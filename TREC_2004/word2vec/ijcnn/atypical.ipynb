# %%
#%run 'word2vec_data.ipynb'
import cPickle as pickle
# %pylab inline

import scipy
import numpy as np
import pandas as pd
#import plotly.plotly as py
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords

from gensim import models


import math
import codecs
import re
import string
from time import time


## Sklearn
from sklearn import svm, datasets
import sklearn

from sklearn.feature_extraction.text import HashingVectorizer
from sklearn import metrics
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, roc_auc_score, accuracy_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, label_binarize, Imputer, OneHotEncoder
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, BaggingClassifier, RandomTreesEmbedding
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB
from sklearn import linear_model
from sklearn.linear_model import SGDClassifier
from sklearn import datasets, feature_selection, cluster, feature_extraction
from sklearn import neighbors, decomposition, metrics
from sklearn import grid_search, decomposition, feature_selection, model_selection

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics


from sklearn.pipeline import Pipeline, make_pipeline
from scipy import interp

#############################
### Matplotlib
import matplotlib.pyplot as plt # module for plotting 
from matplotlib import interactive, font_manager
from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D

#############################
### other stuff
from IPython import display

import os
#import ipyparallel as ipp
import warnings
warnings.filterwarnings('ignore')

# This is here to avoid all the Matplotlib warnings due to current bugs 
# - not a good idea to keep around
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline  

print ("Required Libraries loaded.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Required Libraries loaded.

# %%
#!pip install --upgrade version_information
#%reload_ext version_information
# %load_ext version_information 
# %version_information scipy, numpy, sklearn, pandas, scipy, nltk, gensim, matplotlib, os, cpickle
# Out:
# Software versions
# Python 2.7.12 64bit [MSC v.1500 64 bit (AMD64)]
# IPython 5.1.0
# OS Windows 7 6.1.7601 SP1
# scipy 0.18.1
# numpy 1.11.2
# sklearn 0.18.1
# pandas 0.19.1
# scipy 0.18.1
# nltk 3.2.1
# gensim 0.12.4
# matplotlib 1.5.3
# os The 'os' distribution was not found and is required by the application
# cpickle The 'cpickle' distribution was not found and is required by the application
# Tue Jan 24 13:25:41 2017 GMT Standard Time

# %%
inhibitor  = pd.read_csv("C:\EPC_Data\TREC_BROKEN\No_Mh_Tag/atypicalAntipsychotics_no_mh.csv", sep=",", index_col = "PMID")

# %%
folder = "C:\Users\CR107\Dropbox\PhD\Experiments\TREC_2004\data\word2vec"
filepath = os.path.join(folder, "atypicalAntipsychotics_chi2_features_10minwords_15context")
model = models.Word2Vec.load(filepath)
print ("\nMatrix of word vectors is size : ", model.syn0.shape)
# Out:
# ('\nMatrix of word vectors is size : ', (2255L, 381L))

# %%
#Create feature vectors from the averages of word vectors

def makeFeatureVec(words, model):
    """
    words - list of words (i.e. article) to be used as input for the creation of word vectors
    model - model to use for the creation of the vectors
    
    makeFeatureVec: Function to average all of the word vectors in a given paragraph
    returns: a numpy array of floats that are the average of the constituent word vectors for each word
    """
    num_features = model.syn0.shape[1]
    featureVec = np.zeros((num_features,),dtype="float32")
    nwords = 0.
    # 
    # Index2word is a list that contains the names of the words in 
    # the model's vocabulary. Convert it to a set, for speed 
    index2word_set = set(model.index2word)
    #
    # Loop over each word in the article and, if it is in the model's
    # vocaublary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    # 
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    return featureVec

def getAvgFeatureVecs(articles, model):
    """
    articles - list of articles for which the creation of word vectors needs to be done for each
    model - model to use for the creation of the vectors
    
    getAvgFeatureVecs: Given a set of articles (each one a list of words), calculate 
    the average feature vector for each one and return a 2D numpy array 
    returns: a 2D numpy array that contains the average of the constituent word vectors for each article
    """
    num_features = model.syn0.shape[1]
    articleFeatureVecs = np.zeros((len(articles),num_features),dtype="float32")
    counter = 0.
    
    # Loop through the articles
    for article in articles:
        #
        # Print a status message every 1000th review
        if counter%500. == 0.:
            print ("Article %d of %d" % (counter, len(articles)))
        # 
        # Call the function (defined above) that makes average feature vectors
        articleFeatureVecs[counter] = makeFeatureVec(article, model)
        #
        # Increment the counter
        counter = counter + 1.
    return articleFeatureVecs

# %%
# Import articles for string cleaning

def clean_text(text, stem_words = False, remove_stopwords = False):
    ###clean
    texts = re.sub("[^a-zA-Z]",    #pattern to match
              " ",              #replace other with this
              str(text))                 #text to apply to
         
    #print "Text recived: ", texts 
    clean_corpus = texts.lower().split()
    #print "corpus: ", clean_corpus
    if stem_words:
        # Porter stemmer
        porter = nltk.PorterStemmer()
        # Snowball stemmer
        snowball = nltk.SnowballStemmer('english')
        # Lancaster stemmer
        lancaster = nltk.LancasterStemmer()
        # General stemming Lambda function to stem tokens
        clean_corpus = lambda tokens: [porter.stem(w) for w in corpus]
    if remove_stopwords:   # Optionally remove stop words
        stops = set(stopwords.words("english"))
        clean_corpus = [w for w in clean_corpus if not w in stops]
        #print "Clean_corpus: ", clean_corpus
    
    return (clean_corpus)

# %%
# ****************************************************************
# Calculate average feature vectors for training and testing sets,
# using the functions we defined above. We remove stopwords.

print ("Creating average feature vecs for articles")
cleaned_articles = []
for article in inhibitor.TIABSMh:
    cleaned_articles.append(clean_text(article, stem_words=False, remove_stopwords=True ))

averageWordVecs = getAvgFeatureVecs(cleaned_articles, model)
# Out:
# Creating average feature vecs for articles
# Article 0 of 1115
# Article 500 of 1115
# Article 1000 of 1115

# %%
RANDOM_STATE = 55
TEST_SIZE = 0.2

X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=37)

print (len(X_train))
print (len(X_test))
# Out:
# 892
# 223

# %%
yTrFreq = scipy.stats.itemfreq(inhibitor.Label)
print(yTrFreq)
# Out:
# [[  0 748]
#  [  1 367]]

# %%
def weight(x):
    x = np.where(x==0, 1, 4)
    return x

# %%
clf = SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,decision_function_shape=None, degree=3, 
              gamma='auto', kernel='linear', max_iter=-1, probability=False, random_state=55, shrinking=True,
              tol=0.001, verbose=False)


seeds = [35, 71, 21, 61, 55]

svm_precision = []
svm_recall = []
svm_f = []
acc = []
ps_vectors = []
ns_vectors = []
tr_pos = []
tr_neg = []
te_pos = []
te_neg = []

true_pos = []
true_neg = []
false_pos = []
false_neg = []


for seed in seeds:
    X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=seed)

    w = weight(y_train)
    yTrFreq = scipy.stats.itemfreq(y_train)
    tr_pos = np.append(tr_pos, yTrFreq[1][1])
    tr_neg = np.append(tr_neg, yTrFreq[0][1])

    # print(yTrFreq)



    yTrFreq = scipy.stats.itemfreq(y_test)
    te_pos = np.append(te_pos, yTrFreq[1][1])
    te_neg = np.append(te_neg, yTrFreq[0][1])

    #print(yTrFreq)

    print ("Fitting for Seed = %d" % seed)  

    clf.fit(X_train, y_train, sample_weight = w)
    pred = clf.predict(X_test)

        

    s_vector = clf.n_support_
    s_prec = metrics.precision_score(y_test, pred)#, sample_weight=wt)
    s_recall = metrics.recall_score(y_test, pred)#, sample_weight=wt)
    s_f1 = metrics.f1_score(y_test, pred)#, sample_weight=wt)
    acc_s = metrics.accuracy_score(y_test, pred)
    
    print (metrics.confusion_matrix(y_test, pred))
    true_neg.append(metrics.confusion_matrix(y_test, pred)[0,0])
    true_pos.append(metrics.confusion_matrix(y_test, pred)[1,1])
    false_neg.append(metrics.confusion_matrix(y_test, pred)[1, 0])
    false_pos.append(metrics.confusion_matrix(y_test, pred)[0, 1])
        

    svm_precision.append(s_prec)
    svm_recall.append(s_recall)
    svm_f.append(s_f1)
    acc.append(acc_s)
    ps_vectors = np.append(ps_vectors, s_vector[1])
    ns_vectors = np.append(ns_vectors, s_vector[0])

print ("SVM Cross validation results: ")
print ("Mean Precision: %.2f +/- %.2f "%(np.mean(svm_precision), np.std(svm_precision)))
print ("  Mean  Recall: %.2f +/- %.2f" %(np.mean(svm_recall), np.std(svm_recall)))
print ("      Mean  F1: %.2f +/- %.2f" %(np.mean(svm_f), np.std(svm_f)))
print ("Mean  Accuracy: %.2f +/- %.2f" %(np.mean(acc), np.std(acc)))
print (" True Negative: ", true_neg)
print ("False Negative: ", false_neg)
print (" True Positive: ", true_pos)
print ("False Positive: ", false_pos)
print ("Negative support Vectors: ", ns_vectors)
print ("Positive support Vectors: ", ps_vectors)
print ("Mean positive support vectors: %.2f +/- %.2f"%(np.mean(ps_vectors), np.std(ps_vectors)))
print ("Mean Negative support vectors: %.2f +/- %.2f"%(np.mean(ns_vectors), np.std(ns_vectors)))
print ("Train positive: %.2f" %(np.mean(tr_pos)))
print ("Train negattive: %.2f" %(np.mean(tr_neg)))
print ("Test positive: %.2f" %(np.mean(te_pos)))
print ("Test negative: %.2f" %(np.mean(te_neg)))
# Out:
# Fitting for Seed = 35
# [[ 11 137]
#  [  1  74]]
# Fitting for Seed = 71
# [[ 20 124]
#  [  5  74]]
# Fitting for Seed = 21
# [[ 15 134]
#  [  2  72]]
# Fitting for Seed = 61
# [[ 16 131]
#  [  2  74]]
# Fitting for Seed = 55
# [[ 31 120]
#  [  6  66]]
# SVM Cross validation results:
# Mean Precision: 0.36 +/- 0.01
#   Mean  Recall: 0.96 +/- 0.03
#       Mean  F1: 0.52 +/- 0.01
# Mean  Accuracy: 0.41 +/- 0.02
# (' True Negative: ', [11, 20, 15, 16, 31])
# ('False Negative: ', [1, 5, 2, 2, 6])
# (' True Positive: ', [74, 74, 72, 74, 66])
# ('False Positive: ', [137, 124, 134, 131, 120])
# ('Negative support Vectors: ', array([ 600.,  596.,  595.,  601.,  587.]))
# ('Positive support Vectors: ', array([ 102.,  106.,   99.,  104.,  100.]))
# Mean positive support vectors: 102.20 +/- 2.56
# Mean Negative support vectors: 595.80 +/- 4.96
# Train positive: 291.80
# Train negattive: 600.20
# Test positive: 75.20
# Test negative: 147.80

# %%
##  based on this SciKitLearn example:
# http://scikit-learn.org/stable/auto_examples/text/document_classification_20newsgroups.html

# options
print_report = True
print_cm = True
print_top10 = True
n_features = 2 ** 16
filtered = True

########
# Load some categories from the training set

#RANDOM_STATE = 55

sw_train = weight(y_train)
#sw_test = weight(y_test)

categories = ['Irrelevant', 'Relevant']
print('Training and test datasets created')

def trim(s):
    """Trim string to fit on terminal (assuming 80-column display)"""
    return s if len(s) <= 80 else s[:77] + "..."


########
# Benchmark the classifiers, one at a time
def benchmark(clf, name):
    """
    clf - the classifier
    name - its name
    
    benchmark: to create the benchmark metrics for the classification
    returns: the inputs to the results list
    """
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    try:
        clf.fit(X_train, y_train, sample_weight = sw_train)#with weight
    except:
        clf.fit(X_train, y_train)#no weight
        
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    pred = clf.predict(X_test)
    test_time = time() - t0
    print("test time:  %0.3fs" % test_time)
    
    
    acc_score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % acc_score)
    
    prec_score = metrics.precision_score(y_test, pred)
    print("precision:  %0.3f" % prec_score)
    
    recall = metrics.recall_score(y_test, pred)
    print("recall:     %0.3f" % recall)
    
    # get the decision boundary or the probas.
    if hasattr(clf, "decision_function"):
        y_score = np.array(clf.decision_function(X_test))
    else:
        y_score = clf.predict_proba(X_test)[:,1]
        
    if hasattr(clf, "n_support_"):
        print ("Complexity: ", clf.n_support_)

    auc_score = metrics.roc_auc_score(y_test, y_score)
    print("*** AUC for ROC = %0.3f\n" % auc_score)
    
    #if hasattr(clf, 'coef_'):
    #    print("dimensionality: %d" % clf.coef_.shape[1])
    #    print("density: %f" % density(clf.coef_))
    #    print()

    if print_report:
        print("classification report:")
        print(metrics.classification_report(y_test, pred, target_names=categories))

    if print_cm:
        print("confusion matrix:")
        print(metrics.confusion_matrix(y_test, pred))

    print()
    clf_descr = str(clf).split('(')[0]
    return name, acc_score, auc_score, prec_score, recall, train_time, test_time

def create_results():
    """
    create_results: to run the classification and create the of results 
    from the battery of classifiers
    returns: an multiD list of results
    """
    results = []
    for clf, name in (
            (SVC(kernel="linear", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1.0"),
            (SVC(kernel="linear", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10.0"),
            (SVC(kernel="linear", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=100"),
            (SVC(kernel="linear", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000"),
            (SVC(kernel="linear", C=10000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10000"),
            (SVC(kernel="rbf", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=1"),
            (SVC(kernel="rbf", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=10"),
            (SVC(kernel="rbf", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=100"),
            (SVC(kernel="rbf", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000"),
            (SVC(kernel="rbf", C=10000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10000"),
            ):
        print('=' * 80)
        print(name)
        results.append(benchmark(clf, name))

    for penalty in ["l2", "l1"]:
        print('=' * 80)
        print("%s penalty" % penalty.upper())
        # Train Liblinear model
        results.append(benchmark(LinearSVC(loss='l2', penalty=penalty,
                                                dual=False, tol=1e-3, random_state=RANDOM_STATE, class_weight = 'balanced'), "Linear SVC %s penalty" %penalty))


        # Train SGD model
        results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                               penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD classifier %s penalty" %penalty))
        results.append(benchmark(SGDClassifier(loss="hinge", alpha=.0001, n_iter=50,
                                       penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD hinge loss %s penalty" %penalty))
        results.append(benchmark(SGDClassifier(loss="log", alpha=.0001, n_iter=50,
                                   penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD log loss %s penalty" %penalty))
    return results

def comparison_plots(results):
    """
    results - array containing the results from the classification to plot
    
    yields: prints out the results from each classifier and then finishes with plots of the 
    accuracy scores and ROC AUC scores for all the classifiers
    """
    # Train SGD with Elastic Net penalty
    print('=' * 80)
    print("Elastic-Net penalty")
    results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                           penalty="elasticnet", random_state=RANDOM_STATE, class_weight = 'balanced'),"Elastic-Net penalty"))

    # Train sparse Naive Bayes classifiers
    #print('=' * 80)
    #print("Naive Bayes")
    #results.append(benchmark(MultinomialNB(alpha=.01),"Multinomial Naive Bayes"))
    #results.append(benchmark(BernoulliNB(alpha=.01),"Bernouilli Naive Bayes"))

    #print('=' * 80)
    #print("LinearSVC with L1-based feature selection")
    # The smaller C, the stronger the regularization.
    # The more regularization, the more sparsity.
    #results.append(benchmark(Pipeline([
    #  ('feature_selection', LinearSVC(penalty="l1", dual=False, tol=1e-3, random_state=RANDOM_STATE, class_weight = 'balanced')),
    #  ('classification', LinearSVC())
    #            ]),"LinearSVC - L1 feature selection"))

    ######
    # make some plots

    indices = np.arange(len(results))

    results = [[x[i] for x in results] for i in range(7)]

    clf_names, acc_score, auc_score, prec_score, recall, training_time, test_time = results
    training_time = np.array(training_time) / np.max(training_time)
    test_time = np.array(test_time) / np.max(test_time)

    ######
    #  Make a plot for the accuracy scores 
    plt.figure(figsize=(12, 8))
    plt.title("Accuracy Score")
    plt.barh(indices, acc_score, .2, label="accuracy score", color='r')
    plt.barh(indices + .3, training_time, .2, label="training time", color='g')
    plt.barh(indices + .6, test_time, .2, label="test time", color='b')
    plt.yticks(())
    plt.legend(loc='best')
    plt.subplots_adjust(left=.25)
    plt.subplots_adjust(top=.95)
    plt.subplots_adjust(bottom=.05)
    legend = plt.legend(loc=3,frameon=True,framealpha=0.7)
    rect = legend.get_frame()
    rect.set_facecolor('lightgray')
    rect.set_linewidth(0.2)
    plt.gca().xaxis.grid(True)
    #remove_border()

    for i, c in zip(indices, clf_names):
        plt.text(-.3, i, c)

    plt.show()
    
    ######
    #  Make a plot for the ROC curve AUC scores 
    plt.figure(figsize=(12, 8))
    plt.title("ROC curve AUC Score")
    plt.barh(indices, auc_score, .2, label="AUC score", color='r')
    plt.barh(indices + .3, training_time, .2, label="training time", color='g')
    plt.barh(indices + .6, test_time, .2, label="test time", color='b')
    plt.yticks(())
    plt.legend(loc='best')
    plt.subplots_adjust(left=.25)
    plt.subplots_adjust(top=.95)
    plt.subplots_adjust(bottom=.05)
    legend = plt.legend(loc=3,frameon=True,framealpha=0.7)
    rect = legend.get_frame()
    rect.set_facecolor('lightgray')
    rect.set_linewidth(0.2)
    plt.gca().xaxis.grid(True)
    #remove_border()
    

    for i, c in zip(indices, clf_names):
        plt.text(-.3, i, c)
    plt.show()
# Out:
# Training and test datasets created

# %%
# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# Out:
# ================================================================================
# Linear SVC C=1.0
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.364s
# test time:  0.063s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597, 141]))
# *** AUC for ROC = 0.691
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# Linear SVC C=10.0
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.381s
# test time:  0.047s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597, 106]))
# *** AUC for ROC = 0.704
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# Linear SVC C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.438s
# test time:  0.064s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597,  93]))
# *** AUC for ROC = 0.703
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# Linear SVC C=1000
# ________________________________________________________________________________
# Training:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.519s
# test time:  0.047s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597,  93]))
# *** AUC for ROC = 0.703
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# Linear SVC C=10000
# ________________________________________________________________________________
# Training:
# SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 1.275s
# test time:  0.063s
# accuracy:   0.435
# precision:  0.355
# recall:     0.917
# ('Complexity: ', array([587, 100]))
# *** AUC for ROC = 0.696
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.84      0.21      0.33       151
#    Relevant       0.35      0.92      0.51        72
#
# avg / total       0.68      0.43      0.39       223
#
# confusion matrix:
# [[ 31 120]
#  [  6  66]]
# ()
# ================================================================================
# SVM with RBF kernel C=1
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.350s
# test time:  0.079s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597, 182]))
# *** AUC for ROC = 0.658
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# SVM with RBF kernel C=10
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.366s
# test time:  0.091s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597, 165]))
# *** AUC for ROC = 0.695
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# SVM with RBF kernel C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.350s
# test time:  0.062s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597, 150]))
# *** AUC for ROC = 0.648
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# Linear SVC C=1000
# ________________________________________________________________________________
# Training:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.359s
# test time:  0.065s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597, 109]))
# *** AUC for ROC = 0.712
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# Linear SVC C=10000
# ________________________________________________________________________________
# Training:
# SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.372s
# test time:  0.062s
# accuracy:   0.323
# precision:  0.323
# recall:     1.000
# ('Complexity: ', array([597,  89]))
# *** AUC for ROC = 0.723
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       151
#    Relevant       0.32      1.00      0.49        72
#
# avg / total       0.10      0.32      0.16       223
#
# confusion matrix:
# [[  0 151]
#  [  0  72]]
# ()
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=55, tol=0.001, verbose=0)
# train time: 0.032s
# test time:  0.042s
# accuracy:   0.655
# precision:  0.477
# recall:     0.708
# *** AUC for ROC = 0.726
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.82      0.63      0.71       151
#    Relevant       0.48      0.71      0.57        72
#
# avg / total       0.71      0.65      0.67       223
#
# confusion matrix:
# [[95 56]
#  [21 51]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.038s
# test time:  0.000s
# accuracy:   0.399
# precision:  0.345
# recall:     0.958
# *** AUC for ROC = 0.719
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.87      0.13      0.23       151
#    Relevant       0.34      0.96      0.51        72
#
# avg / total       0.70      0.40      0.32       223
#
# confusion matrix:
# [[ 20 131]
#  [  3  69]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.025s
# test time:  0.000s
# accuracy:   0.399
# precision:  0.345
# recall:     0.958
# *** AUC for ROC = 0.719
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.87      0.13      0.23       151
#    Relevant       0.34      0.96      0.51        72
#
# avg / total       0.70      0.40      0.32       223
#
# confusion matrix:
# [[ 20 131]
#  [  3  69]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.047s
# test time:  0.000s
# accuracy:   0.350
# precision:  0.329
# recall:     0.972
# *** AUC for ROC = 0.733
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.80      0.05      0.10       151
#    Relevant       0.33      0.97      0.49        72
#
# avg / total       0.65      0.35      0.23       223
#
# confusion matrix:
# [[  8 143]
#  [  2  70]]
# ()
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=55, tol=0.001, verbose=0)
# train time: 0.015s
# test time:  0.000s
# accuracy:   0.655
# precision:  0.477
# recall:     0.736
# *** AUC for ROC = 0.712
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.83      0.62      0.71       151
#    Relevant       0.48      0.74      0.58        72
#
# avg / total       0.72      0.65      0.67       223
#
# confusion matrix:
# [[93 58]
#  [19 53]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.122s
# test time:  0.000s
# accuracy:   0.413
# precision:  0.349
# recall:     0.944
# *** AUC for ROC = 0.727
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      0.16      0.27       151
#    Relevant       0.35      0.94      0.51        72
#
# avg / total       0.69      0.41      0.35       223
#
# confusion matrix:
# [[ 24 127]
#  [  4  68]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.137s
# test time:  0.001s
# accuracy:   0.413
# precision:  0.349
# recall:     0.944
# *** AUC for ROC = 0.727
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      0.16      0.27       151
#    Relevant       0.35      0.94      0.51        72
#
# avg / total       0.69      0.41      0.35       223
#
# confusion matrix:
# [[ 24 127]
#  [  4  68]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.170s
# test time:  0.000s
# accuracy:   0.363
# precision:  0.333
# recall:     0.972
# *** AUC for ROC = 0.731
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.85      0.07      0.13       151
#    Relevant       0.33      0.97      0.50        72
#
# avg / total       0.68      0.36      0.25       223
#
# confusion matrix:
# [[ 11 140]
#  [  2  70]]
# ()
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=55, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.114s
# test time:  0.000s
# accuracy:   0.390
# precision:  0.343
# recall:     0.972
# *** AUC for ROC = 0.710
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.89      0.11      0.20       151
#    Relevant       0.34      0.97      0.51        72
#
# avg / total       0.72      0.39      0.30       223
#
# confusion matrix:
# [[ 17 134]
#  [  2  70]]
# ()

# %%
# Function to compute ROC curve and ROC area for each class
# based on the example in SciKitLearn
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html

def plot_ROC_curve(y_test, y_score):
    """
    y_test - truth series, single array
    y_score - prediction series, single array
    
    yields: plot of curve
    The function will plot the ROC curve and an embedded legend with the AUC score.
    """
    sw_test = weight(y_test)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    fpr, tpr, _ = roc_curve(y_test, y_score, sample_weight=sw_test)
    roc_auc = auc(fpr, tpr)
    # Plot all ROC curves
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = {0:0.3f})' .format(roc_auc), linewidth=2)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic curve')
    plt.legend(loc="lower right")
    plt.show()

# Compute Precision-Recall and plot curve
# As above, based on the SciKit Learn example

def plot_PR_curve(y_test, y_score):
    """
    y_test - truth series, single array
    y_score - prediction series, single array
    
    yields: plot of curve
    The function will plot the precision recall curve and an embedded legend with the AUC score.
    """
    sw_test = weight(y_test)
    
    precision = dict()
    recall = dict()
    precision, recall, _ = precision_recall_curve(y_test, y_score, pos_label=1, sample_weight=sw_test)
    
    # Plot Precision-Recall curve for each class
    plt.clf()
    plt.plot(recall, precision, label='Precision-recall curve')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall curve')
    plt.legend(loc="lower right")
    plt.show()

# Convenience function to adjust plot parameters for a clear layout.
target_names = ["Excluded", "Included"]

def show_confusion_matrix(cm):
    """
    cm - confusion matrix parameters as output from confusion_matrix() function
    
    yields: a plot of the confusion matrix with imshow
    Convenience function to adjust confusion matrix plot parameters for a clear layout.
    """
    sw_test = weight(y_test)
    
    plt.figure(figsize=(5, 5))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.binary)
    plt.title('Confusion matrix')
    plt.set_cmap('Blues')
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=60)
    plt.yticks(tick_marks, target_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

def print_stats(clf, x_train, x_test, y_train, y_test):
    """
    clf - classifier
    x_train - matrix of training features
    x_test - matrix of training features
    y_train - array of training labels
    y_test - array of validation truths
    yields: print outs of the full suite of metrics for the classification for both training and validation sets
    """
    print(clf)
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_train)

    print("Number of mislabeled points out of a total %d training points : %d"
          % (x_train.shape[0],(y_train != y_pred).sum()))
    # Output the hit-rate and the confusion matrix for the training set
    print(("The hit rate on the training set: ", clf.score(x_train, y_train)), '\n')
    scores1 = cross_val_score(clf, x_train, y_train, cv=2, scoring = 'accuracy' , n_jobs = 1)
    scores2 = cross_val_score(clf, x_train, y_train, cv=2, scoring = 'f1' , n_jobs = 1)
    report = precision_recall_fscore_support(y_train, y_pred, average='macro')
    acc_score = accuracy_score(y_train, y_pred)#, sample_weight=sw_test)
    cm = confusion_matrix(y_pred, y_train)

    print("\nprecision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f\n" % 
          (report[0], report[1], report[2], acc_score))
    print("\n10-fold CV mean accuracy = %0.3f, mean F1 = %0.3f\n" % 
          (scores1.mean(), scores2.mean()))
    print(pd.DataFrame(cm.astype(np.float64) / cm.sum(axis=1)),"\n")
    print("The confusion matrix on the training set: \n",pd.DataFrame(cm) )
    show_confusion_matrix(cm)

    pred = clf.predict(x_test)

    print("Number of mislabeled points out of a total %d testing points : %d"
          % (x_test.shape[0],(y_test != pred).sum()))
    # Output the hit-rate and the confusion matrix for the training set
    print(("The hit rate on the testing set: ", clf.score(x_test, y_test)), '\n')
    report = precision_recall_fscore_support(y_test, pred, average='macro')
    acc_score = accuracy_score(y_test, pred)
    cm = confusion_matrix(pred, y_test)

    print("\nprecision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f\n" % 
          (report[0], report[1], report[2], acc_score))
    print(pd.DataFrame(cm.astype(np.float64) / cm.sum(axis=1)),"\n")
    print("The confusion matrix on the testing set: \n",pd.DataFrame(cm))
    show_confusion_matrix(cm)

# %%
#RANDOM_STATE = 55


def run_class(X, y, TEST_SIZE):
    """
    X - input matrix of features for the classification
    y - array of truths for the classification 
    TEST_SIZE - number or proportion to use for the test set - int is number, float is precentage
    
    yields: this version runs a battery of classifiers. For each of them, it  
    prints out the performance metrics for the classification and plots the ROC and PR curves
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)    
    
    sw_test = weight(y_test)
    
    for clf, name in (
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced'), "Perceptron50"),
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced', penalty = 'l1'), "Perceptron50l1"),
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced', penalty="l2"), "Perceptron50l2"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced'), "Perceptron20"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced', penalty = 'l1'), "Perceptron20l1"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced', penalty="l2"), "Perceptron20l2"),
            (linear_model.LogisticRegression(C=1e2, random_state=RANDOM_STATE, class_weight='balanced'), "Logistic Regression 1e2"),
            (linear_model.LogisticRegression(C=1e6, random_state=RANDOM_STATE, class_weight='balanced'), "Logistic Regression 1e6"),
            (LinearSVC(C = 1.0, penalty="l2", multi_class = 'crammer_singer', random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC1 L2 penalty"), 
            (LinearSVC(C = 1000, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC1000 L2 penalty"),
            (LinearSVC(C = 100, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC100 L2 penalty"),
            (LinearSVC(C = 1.0, penalty="l1", multi_class = 'crammer_singer', random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC1 L1 penalty"), 
            (LinearSVC(C = 1000, penalty="l1", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC1000 L1 penalty"),
            (LinearSVC(C = 100, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC100 L1 penalty"),
            (SVC(kernel="linear", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1.0"),
            (SVC(kernel="linear", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10.0"),
            (SVC(kernel="linear", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=100.0"),
            (SVC(kernel="linear", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000.0"),
            (SVC(kernel="rbf", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=1"),
            (SVC(kernel="rbf", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=10"),
            (SVC(kernel="rbf", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=100"),
            (MLPClassifier(hidden_layer_sizes=(5, 5), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(10, 10), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(20, 20), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(5, 5), learning_rate='invscaling', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            ):
        
        print("\n", name, "\ntest size is %d %%  " % (TEST_SIZE*100))

        clf.fit(X_train, y_train)
        print (clf.score(X_test, y_test))
        
        mean_acc_score = clf.score(X_test, y_test)
        pred = clf.predict(X_test)

        report = precision_recall_fscore_support(y_test, pred, average='binary', sample_weight=sw_test)
        acc_score = accuracy_score(y_test, pred)
        cm = confusion_matrix(pred, y_test)

        # get the decision boundary or the probas.
        if hasattr(clf, "decision_function"):
            y_score = np.array(clf.decision_function(X_test))
        else:
            y_score = clf.predict_proba(X_test)[:,1]

        auc_score = metrics.roc_auc_score(y_test, y_score, sample_weight=sw_test)

        #print("mean_accuracy = %0.3f" % mean_acc_score)
        print("precision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f" % 
              (report[0], report[1], report[2], acc_score))
        print("The confusion matrix on the testing set:          \n", pd.DataFrame(cm))
        print("*********** AUC for ROC = %0.3f" % auc_score)
                
        plot_ROC_curve(y_test, y_score)
        plot_PR_curve(y_test, y_score)
        #print (y_score[:,:30])

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'class_weight':['balanced', None],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000], 'class_weight':['balanced', None]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# ()
# Best parameters set found on development set:
# ()
# {'kernel': 'linear', 'C': 1000, 'class_weight': None}
# ()
# Grid scores on development set:
# ()
# 0.250 (+/-0.165) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.165) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001, 'class_weight': None}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001, 'class_weight': None}
# 0.250 (+/-0.165) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.165) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001, 'class_weight': None}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001, 'class_weight': None}
# 0.574 (+/-0.073) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001, 'class_weight': None}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001, 'class_weight': None}
# 0.596 (+/-0.032) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.533 (+/-0.008) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001, 'class_weight': None}
# 0.333 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001, 'class_weight': None}
# 0.595 (+/-0.013) for {'kernel': 'linear', 'C': 1, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'class_weight': None}
# 0.602 (+/-0.048) for {'kernel': 'linear', 'C': 10, 'class_weight': 'balanced'}
# 0.492 (+/-0.317) for {'kernel': 'linear', 'C': 10, 'class_weight': None}
# 0.637 (+/-0.020) for {'kernel': 'linear', 'C': 100, 'class_weight': 'balanced'}
# 0.478 (+/-0.290) for {'kernel': 'linear', 'C': 100, 'class_weight': None}
# 0.641 (+/-0.001) for {'kernel': 'linear', 'C': 1000, 'class_weight': 'balanced'}
# 0.660 (+/-0.017) for {'kernel': 'linear', 'C': 1000, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.74      0.90      0.81       229
#           1       0.59      0.32      0.41       106
#
# avg / total       0.69      0.71      0.69       335
#
# ()
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'kernel': 'linear', 'C': 1000, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001, 'class_weight': None}
# 0.583 (+/-0.082) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001, 'class_weight': None}
# 0.607 (+/-0.038) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.532 (+/-0.020) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001, 'class_weight': None}
# 0.605 (+/-0.019) for {'kernel': 'linear', 'C': 1, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'class_weight': None}
# 0.614 (+/-0.055) for {'kernel': 'linear', 'C': 10, 'class_weight': 'balanced'}
# 0.530 (+/-0.059) for {'kernel': 'linear', 'C': 10, 'class_weight': None}
# 0.653 (+/-0.023) for {'kernel': 'linear', 'C': 100, 'class_weight': 'balanced'}
# 0.544 (+/-0.087) for {'kernel': 'linear', 'C': 100, 'class_weight': None}
# 0.657 (+/-0.004) for {'kernel': 'linear', 'C': 1000, 'class_weight': 'balanced'}
# 0.612 (+/-0.015) for {'kernel': 'linear', 'C': 1000, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.84      0.69      0.75       229
#           1       0.51      0.71      0.59       106
#
# avg / total       0.73      0.69      0.70       335
#
# ()

# %%
# Set the parameters by cross-validation
#linearsvc


tuned_parameters = [{'C': [1.0, 10, 100, 1000],
                     #'penalty': ['l2', 'l1'],
                     'class_weight':['balanced', None],
                     #'loss': ['squared_hinge', 'hinge'],
                     #'dual': [True, False],
                     'multi_class': ['crammer_singer', 'ovr']
                     }]

                    
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(LinearSVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# ()
# Best parameters set found on development set:
# ()
# {'multi_class': 'crammer_singer', 'C': 100, 'class_weight': None}
# ()
# Grid scores on development set:
# ()
# 0.595 (+/-0.037) for {'multi_class': 'crammer_singer', 'C': 1.0, 'class_weight': 'balanced'}
# 0.604 (+/-0.059) for {'multi_class': 'ovr', 'C': 1.0, 'class_weight': 'balanced'}
# 0.333 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'class_weight': None}
# 0.697 (+/-0.128) for {'multi_class': 'ovr', 'C': 1.0, 'class_weight': None}
# 0.604 (+/-0.028) for {'multi_class': 'crammer_singer', 'C': 10, 'class_weight': 'balanced'}
# 0.626 (+/-0.034) for {'multi_class': 'ovr', 'C': 10, 'class_weight': 'balanced'}
# 0.484 (+/-0.302) for {'multi_class': 'crammer_singer', 'C': 10, 'class_weight': None}
# 0.650 (+/-0.092) for {'multi_class': 'ovr', 'C': 10, 'class_weight': None}
# 0.640 (+/-0.009) for {'multi_class': 'crammer_singer', 'C': 100, 'class_weight': 'balanced'}
# 0.641 (+/-0.006) for {'multi_class': 'ovr', 'C': 100, 'class_weight': 'balanced'}
# 0.730 (+/-0.207) for {'multi_class': 'crammer_singer', 'C': 100, 'class_weight': None}
# 0.644 (+/-0.001) for {'multi_class': 'ovr', 'C': 100, 'class_weight': None}
# 0.647 (+/-0.014) for {'multi_class': 'crammer_singer', 'C': 1000, 'class_weight': 'balanced'}
# 0.654 (+/-0.044) for {'multi_class': 'ovr', 'C': 1000, 'class_weight': 'balanced'}
# 0.657 (+/-0.051) for {'multi_class': 'crammer_singer', 'C': 1000, 'class_weight': None}
# 0.682 (+/-0.120) for {'multi_class': 'ovr', 'C': 1000, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.72      0.92      0.81       229
#           1       0.56      0.22      0.31       106
#
# avg / total       0.67      0.70      0.65       335
#
# ()
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'multi_class': 'crammer_singer', 'C': 1000, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.606 (+/-0.044) for {'multi_class': 'crammer_singer', 'C': 1.0, 'class_weight': 'balanced'}
# 0.616 (+/-0.067) for {'multi_class': 'ovr', 'C': 1.0, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'class_weight': None}
# 0.560 (+/-0.010) for {'multi_class': 'ovr', 'C': 1.0, 'class_weight': None}
# 0.616 (+/-0.032) for {'multi_class': 'crammer_singer', 'C': 10, 'class_weight': 'balanced'}
# 0.642 (+/-0.038) for {'multi_class': 'ovr', 'C': 10, 'class_weight': 'balanced'}
# 0.533 (+/-0.066) for {'multi_class': 'crammer_singer', 'C': 10, 'class_weight': None}
# 0.577 (+/-0.022) for {'multi_class': 'ovr', 'C': 10, 'class_weight': None}
# 0.657 (+/-0.011) for {'multi_class': 'crammer_singer', 'C': 100, 'class_weight': 'balanced'}
# 0.661 (+/-0.000) for {'multi_class': 'ovr', 'C': 100, 'class_weight': 'balanced'}
# 0.546 (+/-0.083) for {'multi_class': 'crammer_singer', 'C': 100, 'class_weight': None}
# 0.598 (+/-0.009) for {'multi_class': 'ovr', 'C': 100, 'class_weight': None}
# 0.668 (+/-0.014) for {'multi_class': 'crammer_singer', 'C': 1000, 'class_weight': 'balanced'}
# 0.541 (+/-0.002) for {'multi_class': 'ovr', 'C': 1000, 'class_weight': 'balanced'}
# 0.627 (+/-0.061) for {'multi_class': 'crammer_singer', 'C': 1000, 'class_weight': None}
# 0.517 (+/-0.016) for {'multi_class': 'ovr', 'C': 1000, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.84      0.72      0.77       229
#           1       0.54      0.71      0.61       106
#
# avg / total       0.74      0.71      0.72       335
#
# ()

# %%
# Set the parameters by cross-validation
#PERCEPTRON
tuned_parameters = [{'n_iter': [2, 5, 10,50],
                     'penalty': [None, 'l2', 'l1', 'elasticnet'],
                     'alpha': [0.001, 0.0001, 0.00001],
                     'class_weight':['balanced', None]
                    }]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(Perceptron(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# ()
# Best parameters set found on development set:
# ()
# {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# ()
# Grid scores on development set:
# ()
# 0.606 (+/-0.212) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.250 (+/-0.165) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.250 (+/-0.165) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.250 (+/-0.165) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.588 (+/-0.018) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.537 (+/-0.140) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.167 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.537 (+/-0.140) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.625 (+/-0.068) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.455 (+/-0.243) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.646 (+/-0.060) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.455 (+/-0.243) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.589 (+/-0.021) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.374 (+/-0.412) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.375 (+/-0.414) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.374 (+/-0.412) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.460 (+/-0.253) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.452 (+/-0.237) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.250 (+/-0.165) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.452 (+/-0.237) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.606 (+/-0.068) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.584 (+/-0.022) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.696 (+/-0.278) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.584 (+/-0.022) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.462 (+/-0.258) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.555 (+/-0.443) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.583 (+/-0.503) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.555 (+/-0.443) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.383 (+/-0.430) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.363 (+/-0.391) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.399 (+/-0.134) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.363 (+/-0.391) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.606 (+/-0.212) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.637 (+/-0.187) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.250 (+/-0.165) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.637 (+/-0.187) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.588 (+/-0.018) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.578 (+/-0.010) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.394 (+/-0.454) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.578 (+/-0.010) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.625 (+/-0.068) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.661 (+/-0.077) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.614 (+/-0.112) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.661 (+/-0.077) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.589 (+/-0.021) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.559 (+/-0.068) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.368 (+/-0.400) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.559 (+/-0.068) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.460 (+/-0.253) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.462 (+/-0.257) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.460 (+/-0.254) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.462 (+/-0.257) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.606 (+/-0.068) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.564 (+/-0.017) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.575 (+/-0.010) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.564 (+/-0.017) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.462 (+/-0.258) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.333 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.506 (+/-0.345) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.333 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.383 (+/-0.430) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.387 (+/-0.440) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.364 (+/-0.393) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.387 (+/-0.440) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.606 (+/-0.212) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.640 (+/-0.145) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.630 (+/-0.223) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.640 (+/-0.145) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.588 (+/-0.018) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.580 (+/-0.007) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.574 (+/-0.057) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.580 (+/-0.007) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.625 (+/-0.068) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.642 (+/-0.144) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.634 (+/-0.135) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.642 (+/-0.144) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.589 (+/-0.021) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.366 (+/-0.396) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.362 (+/-0.388) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.366 (+/-0.396) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.460 (+/-0.253) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.459 (+/-0.251) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.457 (+/-0.248) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.459 (+/-0.251) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.606 (+/-0.068) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.600 (+/-0.036) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.567 (+/-0.025) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.600 (+/-0.036) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.462 (+/-0.258) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.333 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.333 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.333 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.383 (+/-0.430) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# 0.393 (+/-0.450) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# 0.385 (+/-0.436) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# 0.393 (+/-0.450) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       229
#           1       0.32      1.00      0.48       106
#
# avg / total       0.10      0.32      0.15       335
#
# ()
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.561 (+/-0.123) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.586 (+/-0.005) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.559 (+/-0.122) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.559 (+/-0.122) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.622 (+/-0.059) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.541 (+/-0.083) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.614 (+/-0.022) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.541 (+/-0.083) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.527 (+/-0.035) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.529 (+/-0.058) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.529 (+/-0.058) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.529 (+/-0.058) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.537 (+/-0.074) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.528 (+/-0.056) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.528 (+/-0.056) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'class_weight': None}
# 0.585 (+/-0.011) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.553 (+/-0.041) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.513 (+/-0.002) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.553 (+/-0.041) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'class_weight': None}
# 0.551 (+/-0.101) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.512 (+/-0.025) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.506 (+/-0.012) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.512 (+/-0.025) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'class_weight': None}
# 0.551 (+/-0.101) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.525 (+/-0.051) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.499 (+/-0.002) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.525 (+/-0.051) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'class_weight': None}
# 0.561 (+/-0.123) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.553 (+/-0.098) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.553 (+/-0.098) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.586 (+/-0.005) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.545 (+/-0.060) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.567 (+/-0.134) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.545 (+/-0.060) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.622 (+/-0.059) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.563 (+/-0.022) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.541 (+/-0.048) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.563 (+/-0.022) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.527 (+/-0.035) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.540 (+/-0.076) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.524 (+/-0.049) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.540 (+/-0.076) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.537 (+/-0.074) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.544 (+/-0.087) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.531 (+/-0.062) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.544 (+/-0.087) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'class_weight': None}
# 0.585 (+/-0.011) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.544 (+/-0.029) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.537 (+/-0.004) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.544 (+/-0.029) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'class_weight': None}
# 0.551 (+/-0.101) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.526 (+/-0.051) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'class_weight': None}
# 0.551 (+/-0.101) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.559 (+/-0.117) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.515 (+/-0.029) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.559 (+/-0.117) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'class_weight': None}
# 0.561 (+/-0.123) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.573 (+/-0.100) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.559 (+/-0.109) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.573 (+/-0.100) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': 'balanced'}
# 0.586 (+/-0.005) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.553 (+/-0.056) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.553 (+/-0.079) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.553 (+/-0.056) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': 'balanced'}
# 0.622 (+/-0.059) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.553 (+/-0.048) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.586 (+/-0.023) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.553 (+/-0.048) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': 'balanced'}
# 0.527 (+/-0.035) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.511 (+/-0.021) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.509 (+/-0.018) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.511 (+/-0.021) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': 'balanced'}
# 0.537 (+/-0.074) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.536 (+/-0.072) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.538 (+/-0.076) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.536 (+/-0.072) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'class_weight': None}
# 0.585 (+/-0.011) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.584 (+/-0.016) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.548 (+/-0.058) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.584 (+/-0.016) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'class_weight': None}
# 0.551 (+/-0.101) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'class_weight': None}
# 0.551 (+/-0.101) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# 0.555 (+/-0.110) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# 0.553 (+/-0.107) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# 0.555 (+/-0.110) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.50      0.00      0.01       229
#           1       0.32      0.99      0.48       106
#
# avg / total       0.44      0.32      0.16       335
#
# ()

# %%
##run 2
RANDOM_STATE = 61


# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)
# Out:
# ================================================================================
# Perceptron50
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty=None,
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.113s
# test time:  0.052s
# accuracy:   0.408
# precision:  0.358
# recall:     0.960
# *** AUC for ROC = 0.733
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      0.13      0.22       296
#    Relevant       0.36      0.96      0.52       150
#
# avg / total       0.69      0.41      0.32       446
#
# confusion matrix:
# [[ 38 258]
#  [  6 144]]
# ()
# ================================================================================
# Perceptron50l1
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty='l1',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.571s
# test time:  0.002s
# accuracy:   0.339
# precision:  0.336
# recall:     0.987
# *** AUC for ROC = 0.717
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.60      0.01      0.02       296
#    Relevant       0.34      0.99      0.50       150
#
# avg / total       0.51      0.34      0.18       446
#
# confusion matrix:
# [[  3 293]
#  [  2 148]]
# ()
# ================================================================================
# Perceptron50l2
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty='l2',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.124s
# test time:  0.043s
# accuracy:   0.370
# precision:  0.346
# recall:     0.980
# *** AUC for ROC = 0.701
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      0.06      0.11       296
#    Relevant       0.35      0.98      0.51       150
#
# avg / total       0.69      0.37      0.25       446
#
# confusion matrix:
# [[ 18 278]
#  [  3 147]]
# ()
# ================================================================================
# Perceptron20
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty=None,
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.028s
# test time:  0.042s
# accuracy:   0.664
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.696
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.66      1.00      0.80       296
#    Relevant       0.00      0.00      0.00       150
#
# avg / total       0.44      0.66      0.53       446
#
# confusion matrix:
# [[296   0]
#  [150   0]]
# ()
# ================================================================================
# Perceptron20l1
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty='l1',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.304s
# test time:  0.043s
# accuracy:   0.664
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.711
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.66      1.00      0.80       296
#    Relevant       0.00      0.00      0.00       150
#
# avg / total       0.44      0.66      0.53       446
#
# confusion matrix:
# [[296   0]
#  [150   0]]
# ()
# ================================================================================
# Perceptron20l2
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty='l2',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.071s
# test time:  0.042s
# accuracy:   0.664
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.716
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.66      1.00      0.80       296
#    Relevant       0.00      0.00      0.00       150
#
# avg / total       0.44      0.66      0.53       446
#
# confusion matrix:
# [[296   0]
#  [150   0]]
# ()
# ================================================================================
# Logistic Regression 1e2
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=100.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=61,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# train time: 0.471s
# test time:  0.033s
# accuracy:   0.670
# precision:  0.507
# recall:     0.747
# *** AUC for ROC = 0.756
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.83      0.63      0.72       296
#    Relevant       0.51      0.75      0.60       150
#
# avg / total       0.72      0.67      0.68       446
#
# confusion matrix:
# [[187 109]
#  [ 38 112]]
# ()
# ================================================================================
# Logistic Regression 1e6
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=1000000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=61,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# train time: 3.192s
# test time:  0.002s
# accuracy:   0.720
# precision:  0.568
# recall:     0.693
# *** AUC for ROC = 0.767
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.83      0.73      0.78       296
#    Relevant       0.57      0.69      0.62       150
#
# avg / total       0.74      0.72      0.73       446
#
# confusion matrix:
# [[217  79]
#  [ 46 104]]
# ()
# ================================================================================
# Linear SVC C=0.025
# ________________________________________________________________________________
# Training:
# SVC(C=0.025, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.660s
# test time:  0.446s
# accuracy:   0.336
# precision:  0.336
# recall:     1.000
# ('Complexity: ', array([452, 207]))
# *** AUC for ROC = 0.655
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       296
#    Relevant       0.34      1.00      0.50       150
#
# avg / total       0.11      0.34      0.17       446
#
# confusion matrix:
# [[  0 296]
#  [  0 150]]
# ()
# ================================================================================
# Linear SVC C=1.05
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.627s
# test time:  0.393s
# accuracy:   0.632
# precision:  0.465
# recall:     0.620
# ('Complexity: ', array([402, 190]))
# *** AUC for ROC = 0.693
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.77      0.64      0.70       296
#    Relevant       0.47      0.62      0.53       150
#
# avg / total       0.67      0.63      0.64       446
#
# confusion matrix:
# [[189 107]
#  [ 57  93]]
# ()
# ================================================================================
# Linear SVC L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=61, tol=0.0001,
#      verbose=0)
# train time: 0.109s
# test time:  0.002s
# accuracy:   0.659
# precision:  0.495
# recall:     0.687
# *** AUC for ROC = 0.715
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.80      0.65      0.72       296
#    Relevant       0.50      0.69      0.58       150
#
# avg / total       0.70      0.66      0.67       446
#
# confusion matrix:
# [[191 105]
#  [ 47 103]]
# ()
# ================================================================================
# SVM with RBF kernel C=1
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.686s
# test time:  0.446s
# accuracy:   0.336
# precision:  0.336
# recall:     1.000
# ('Complexity: ', array([452, 207]))
# *** AUC for ROC = 0.656
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       296
#    Relevant       0.34      1.00      0.50       150
#
# avg / total       0.11      0.34      0.17       446
#
# confusion matrix:
# [[  0 296]
#  [  0 150]]
# ()
# ================================================================================
# SVM with RBF kernel C=10
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.688s
# test time:  0.440s
# accuracy:   0.336
# precision:  0.336
# recall:     1.000
# ('Complexity: ', array([452, 207]))
# *** AUC for ROC = 0.655
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       296
#    Relevant       0.34      1.00      0.50       150
#
# avg / total       0.11      0.34      0.17       446
#
# confusion matrix:
# [[  0 296]
#  [  0 150]]
# ()
# ================================================================================
# SVM with RBF kernel C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.683s
# test time:  0.413s
# accuracy:   0.594
# precision:  0.433
# recall:     0.673
# ('Complexity: ', array([430, 198]))
# *** AUC for ROC = 0.670
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.77      0.55      0.64       296
#    Relevant       0.43      0.67      0.53       150
#
# avg / total       0.66      0.59      0.61       446
#
# confusion matrix:
# [[164 132]
#  [ 49 101]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 100.798s
# test time:  0.139s
# accuracy:   0.664
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.500
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.66      1.00      0.80       296
#    Relevant       0.00      0.00      0.00       150
#
# avg / total       0.44      0.66      0.53       446
#
# confusion matrix:
# [[296   0]
#  [150   0]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10, 10), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 72.968s
# test time:  0.018s
# accuracy:   0.713
# precision:  0.720
# recall:     0.240
# *** AUC for ROC = 0.698
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.71      0.95      0.82       296
#    Relevant       0.72      0.24      0.36       150
#
# avg / total       0.71      0.71      0.66       446
#
# confusion matrix:
# [[282  14]
#  [114  36]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 19.865s
# test time:  0.041s
# accuracy:   0.702
# precision:  0.644
# recall:     0.253
# *** AUC for ROC = 0.713
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.71      0.93      0.81       296
#    Relevant       0.64      0.25      0.36       150
#
# avg / total       0.69      0.70      0.66       446
#
# confusion matrix:
# [[275  21]
#  [112  38]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5), learning_rate='invscaling',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 79.821s
# test time:  0.077s
# accuracy:   0.664
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.500
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.66      1.00      0.80       296
#    Relevant       0.00      0.00      0.00       150
#
# avg / total       0.44      0.66      0.53       446
#
# confusion matrix:
# [[296   0]
#  [150   0]]
# ()
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=61, tol=0.001, verbose=0)
# train time: 0.404s
# test time:  0.108s
# accuracy:   0.659
# precision:  0.495
# recall:     0.687
# *** AUC for ROC = 0.715
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.80      0.65      0.72       296
#    Relevant       0.50      0.69      0.58       150
#
# avg / total       0.70      0.66      0.67       446
#
# confusion matrix:
# [[191 105]
#  [ 47 103]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.259s
# test time:  0.073s
# accuracy:   0.363
# precision:  0.343
# recall:     0.973
# *** AUC for ROC = 0.734
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.80      0.05      0.10       296
#    Relevant       0.34      0.97      0.51       150
#
# avg / total       0.65      0.36      0.24       446
#
# confusion matrix:
# [[ 16 280]
#  [  4 146]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.230s
# test time:  0.002s
# accuracy:   0.363
# precision:  0.343
# recall:     0.973
# *** AUC for ROC = 0.734
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.80      0.05      0.10       296
#    Relevant       0.34      0.97      0.51       150
#
# avg / total       0.65      0.36      0.24       446
#
# confusion matrix:
# [[ 16 280]
#  [  4 146]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.232s
# test time:  0.078s
# accuracy:   0.341
# precision:  0.336
# recall:     0.980
# *** AUC for ROC = 0.728
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.62      0.02      0.03       296
#    Relevant       0.34      0.98      0.50       150
#
# avg / total       0.53      0.34      0.19       446
#
# confusion matrix:
# [[  5 291]
#  [  3 147]]
# ()
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=61, tol=0.001, verbose=0)
# train time: 0.108s
# test time:  0.073s
# accuracy:   0.646
# precision:  0.481
# recall:     0.667
# *** AUC for ROC = 0.704
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.79      0.64      0.70       296
#    Relevant       0.48      0.67      0.56       150
#
# avg / total       0.69      0.65      0.66       446
#
# confusion matrix:
# [[188 108]
#  [ 50 100]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.904s
# test time:  0.051s
# accuracy:   0.354
# precision:  0.340
# recall:     0.980
# *** AUC for ROC = 0.733
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.79      0.04      0.07       296
#    Relevant       0.34      0.98      0.51       150
#
# avg / total       0.64      0.35      0.22       446
#
# confusion matrix:
# [[ 11 285]
#  [  3 147]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.880s
# test time:  0.072s
# accuracy:   0.354
# precision:  0.340
# recall:     0.980
# *** AUC for ROC = 0.733
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.79      0.04      0.07       296
#    Relevant       0.34      0.98      0.51       150
#
# avg / total       0.64      0.35      0.22       446
#
# confusion matrix:
# [[ 11 285]
#  [  3 147]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 1.198s
# test time:  0.002s
# accuracy:   0.343
# precision:  0.337
# recall:     0.987
# *** AUC for ROC = 0.727
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.71      0.02      0.03       296
#    Relevant       0.34      0.99      0.50       150
#
# avg / total       0.59      0.34      0.19       446
#
# confusion matrix:
# [[  5 291]
#  [  2 148]]
# ()
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=61, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.839s
# test time:  0.002s
# accuracy:   0.348
# precision:  0.338
# recall:     0.980
# *** AUC for ROC = 0.733
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.73      0.03      0.05       296
#    Relevant       0.34      0.98      0.50       150
#
# avg / total       0.60      0.35      0.20       446
#
# confusion matrix:
# [[  8 288]
#  [  3 147]]
# ()
# ('\n', 'Perceptron50', '\ntest size is 40 %  ')
# 0.336322869955
# precision = 0.670, recall = 1.000, F1 = 0.802, accuracy = 0.336
# ('The confusion matrix on the testing set:          \n',      0    1
# 0    0    0
# 1  296  150)
# *********** AUC for ROC = 0.751
# ('\n', 'Perceptron50l1', '\ntest size is 40 %  ')
# 0.428251121076
# precision = 0.696, recall = 0.933, F1 = 0.797, accuracy = 0.428
# ('The confusion matrix on the testing set:          \n',      0    1
# 0   51   10
# 1  245  140)
# *********** AUC for ROC = 0.711
# ('\n', 'Perceptron50l2', '\ntest size is 40 %  ')
# 0.394618834081
# precision = 0.686, recall = 0.967, F1 = 0.803, accuracy = 0.395
# ('The confusion matrix on the testing set:          \n',      0    1
# 0   31    5
# 1  265  145)
# *********** AUC for ROC = 0.716
# ('\n', 'Perceptron20', '\ntest size is 40 %  ')
# 0.681614349776
# precision = 0.952, recall = 0.067, F1 = 0.125, accuracy = 0.682
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  294  140
# 1    2   10)
# *********** AUC for ROC = 0.733
# ('\n', 'Perceptron20l1', '\ntest size is 40 %  ')
# 0.663677130045
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.664
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  296  150
# 1    0    0)
# *********** AUC for ROC = 0.705
# ('\n', 'Perceptron20l2', '\ntest size is 40 %  ')
# 0.717488789238
# precision = 0.932, recall = 0.227, F1 = 0.365, accuracy = 0.717
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  286  116
# 1   10   34)
# *********** AUC for ROC = 0.697
# ('\n', 'Logistic Regression 1e2', '\ntest size is 40 %  ')
# 0.681614349776
# precision = 0.812, recall = 0.720, F1 = 0.763, accuracy = 0.682
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  196   42
# 1  100  108)
# *********** AUC for ROC = 0.754
# ('\n', 'Logistic Regression 1e6', '\ntest size is 40 %  ')
# 0.708520179372
# precision = 0.833, recall = 0.667, F1 = 0.741, accuracy = 0.709
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  216   50
# 1   80  100)
# *********** AUC for ROC = 0.778
# ('\n', 'Linear SVC C=0.025', '\ntest size is 40 %  ')
# 0.336322869955
# precision = 0.670, recall = 1.000, F1 = 0.802, accuracy = 0.336
# ('The confusion matrix on the testing set:          \n',      0    1
# 0    0    0
# 1  296  150)
# *********** AUC for ROC = 0.656
# ('\n', 'Linear SVC C=1.05', '\ntest size is 40 %  ')
# 0.630044843049
# precision = 0.775, recall = 0.620, F1 = 0.689, accuracy = 0.630
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  188  57
# 1  108  93)
# *********** AUC for ROC = 0.688
# ('\n', 'Linear SVC L2 penalty', '\ntest size is 40 %  ')
# 0.659192825112
# precision = 0.797, recall = 0.687, F1 = 0.738, accuracy = 0.659
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  191   47
# 1  105  103)
# *********** AUC for ROC = 0.715
# ('\n', 'SVM with RBF kernel C=1', '\ntest size is 40 %  ')
# 0.336322869955
# precision = 0.670, recall = 1.000, F1 = 0.802, accuracy = 0.336
# ('The confusion matrix on the testing set:          \n',      0    1
# 0    0    0
# 1  296  150)
# *********** AUC for ROC = 0.656
# ('\n', 'SVM with RBF kernel C=10', '\ntest size is 40 %  ')
# 0.663677130045
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.664
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  296  150
# 1    0    0)
# *********** AUC for ROC = 0.656
# ('\n', 'SVM with RBF kernel C=100', '\ntest size is 40 %  ')
# 0.585201793722
# precision = 0.748, recall = 0.667, F1 = 0.705, accuracy = 0.585
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  161   50
# 1  135  100)
# *********** AUC for ROC = 0.662
# ('\n', 'MLP5adaptive', '\ntest size is 40 %  ')
# 0.663677130045
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.664
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  296  150
# 1    0    0)
# *********** AUC for ROC = 0.500
# ('\n', 'MLP5adaptive', '\ntest size is 40 %  ')
# 0.713004484305
# precision = 0.911, recall = 0.240, F1 = 0.380, accuracy = 0.713
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  282  114
# 1   14   36)
# *********** AUC for ROC = 0.698
# ('\n', 'MLP5adaptive', '\ntest size is 40 %  ')
# 0.701793721973
# precision = 0.879, recall = 0.253, F1 = 0.393, accuracy = 0.702
# ('The confusion matrix on the testing set:          \n',      0    1
# 0  275  112
# 1   21   38)
# *********** AUC for ROC = 0.713

# %%
#run 3
RANDOM_STATE = 21

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)

# %%
#run 4
RANDOM_STATE =71

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)

# %%
#run 5
RANDOM_STATE = 35


# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)
