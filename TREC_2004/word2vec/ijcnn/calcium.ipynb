# %%
#%run 'word2vec_data.ipynb'
import cPickle as pickle
# %pylab inline

import scipy
import numpy as np
import pandas as pd
#import plotly.plotly as py
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords

from gensim import models


import math
import codecs
import re
import string
from time import time


## Sklearn
from sklearn import svm, datasets
import sklearn

from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, roc_auc_score, accuracy_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, label_binarize, Imputer, OneHotEncoder
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, BaggingClassifier, RandomTreesEmbedding
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB
from sklearn import linear_model
from sklearn.linear_model import SGDClassifier
from sklearn import datasets, feature_selection, cluster, feature_extraction
from sklearn import neighbors, decomposition, metrics
from sklearn import decomposition, feature_selection, model_selection
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics


from sklearn.pipeline import Pipeline, make_pipeline
from scipy import interp

#############################
### Matplotlib
import matplotlib.pyplot as plt # module for plotting 
from matplotlib import interactive, font_manager
from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D

#############################
### other stuff
from IPython import display

import os
#import ipyparallel as ipp
import warnings
warnings.filterwarnings('ignore')

# This is here to avoid all the Matplotlib warnings due to current bugs 
# - not a good idea to keep around
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline  

print ("Required Libraries loaded.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Required Libraries loaded.

# %%
#!pip install --upgrade version_information
#%reload_ext version_information
# %load_ext version_information 
# %version_information scipy, numpy, sklearn, pandas, scipy, nltk, gensim, matplotlib, os, cpickle
# Out:
# Software versions
# Python 2.7.12 64bit [MSC v.1500 64 bit (AMD64)]
# IPython 5.1.0
# OS Windows 7 6.1.7601 SP1
# scipy 0.18.1
# numpy 1.11.2
# sklearn 0.18.1
# pandas 0.19.1
# scipy 0.18.1
# nltk 3.2.1
# gensim 0.12.4
# matplotlib 1.5.3
# os The 'os' distribution was not found and is required by the application
# cpickle The 'cpickle' distribution was not found and is required by the application
# Tue Jan 24 16:33:15 2017 GMT Standard Time

# %%
inhibitor  = pd.read_csv("C:\EPC_Data\TREC_BROKEN\No_Mh_Tag/calciumChannelBlockers_no_mh.csv", sep=",", index_col = "PMID")

# %%
folder = "C:\Users\CR107\Dropbox\PhD\Experiments\TREC_2004\data\word2vec"
filepath = os.path.join(folder, "calciumChannelBlockers_chi2_features_10minwords_15context")
model = models.Word2Vec.load(filepath)
print ("\nMatrix of word vectors is size : ", model.syn0.shape)
# Out:
# ('\nMatrix of word vectors is size : ', (2515L, 329L))

# %%
#Create feature vectors from the averages of word vectors

def makeFeatureVec(words, model):
    """
    words - list of words (i.e. article) to be used as input for the creation of word vectors
    model - model to use for the creation of the vectors
    
    makeFeatureVec: Function to average all of the word vectors in a given paragraph
    returns: a numpy array of floats that are the average of the constituent word vectors for each word
    """
    num_features = model.syn0.shape[1]
    featureVec = np.zeros((num_features,),dtype="float32")
    nwords = 0.
    # 
    # Index2word is a list that contains the names of the words in 
    # the model's vocabulary. Convert it to a set, for speed 
    index2word_set = set(model.index2word)
    #
    # Loop over each word in the article and, if it is in the model's
    # vocaublary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    # 
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    return featureVec

def getAvgFeatureVecs(articles, model):
    """
    articles - list of articles for which the creation of word vectors needs to be done for each
    model - model to use for the creation of the vectors
    
    getAvgFeatureVecs: Given a set of articles (each one a list of words), calculate 
    the average feature vector for each one and return a 2D numpy array 
    returns: a 2D numpy array that contains the average of the constituent word vectors for each article
    """
    num_features = model.syn0.shape[1]
    articleFeatureVecs = np.zeros((len(articles),num_features),dtype="float32")
    counter = 0.
    
    # Loop through the articles
    for article in articles:
        #
        # Print a status message every 1000th review
        if counter%500. == 0.:
            print ("Article %d of %d" % (counter, len(articles)))
        # 
        # Call the function (defined above) that makes average feature vectors
        articleFeatureVecs[counter] = makeFeatureVec(article, model)
        #
        # Increment the counter
        counter = counter + 1.
    return articleFeatureVecs

# %%
# Import articles for string cleaning

def clean_text(text, stem_words = False, remove_stopwords = False):
    ###clean
    texts = re.sub("[^a-zA-Z]",    #pattern to match
              " ",              #replace other with this
              str(text))                 #text to apply to
         
    #print "Text recived: ", texts 
    clean_corpus = texts.lower().split()
    #print "corpus: ", clean_corpus
    if stem_words:
        # Porter stemmer
        porter = nltk.PorterStemmer()
        # Snowball stemmer
        snowball = nltk.SnowballStemmer('english')
        # Lancaster stemmer
        lancaster = nltk.LancasterStemmer()
        # General stemming Lambda function to stem tokens
        clean_corpus = lambda tokens: [porter.stem(w) for w in corpus]
    if remove_stopwords:   # Optionally remove stop words
        stops = set(stopwords.words("english"))
        clean_corpus = [w for w in clean_corpus if not w in stops]
        #print "Clean_corpus: ", clean_corpus
    
    return (clean_corpus)

# %%
# ****************************************************************
# Calculate average feature vectors for training and testing sets,
# using the functions we defined above. We remove stopwords.

print ("Creating average feature vecs for articles")
cleaned_articles = []
for article in inhibitor.TIABSMh:
    cleaned_articles.append(clean_text(article, stem_words=False, remove_stopwords=True ))

averageWordVecs = getAvgFeatureVecs(cleaned_articles, model)
# Out:
# Creating average feature vecs for articles
# Article 0 of 1190
# Article 500 of 1190
# Article 1000 of 1190

# %%
RANDOM_STATE = 55
TEST_SIZE = 0.3

X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=37)

print (len(X_train))
print (len(X_test))
# Out:
# 833
# 357

# %%
yTrFreq = scipy.stats.itemfreq(inhibitor.Label)
print(yTrFreq)
# Out:
# [[  0 987]
#  [  1 203]]

# %%
def weight(x):
    x = np.where(x==0, 1, 4)
    return x

# %%
clf = SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,decision_function_shape=None, degree=3, 
              gamma='auto', kernel='linear', max_iter=-1, probability=False, random_state=55, shrinking=True,
              tol=0.001, verbose=False)

seeds = [35, 71, 21, 61, 55]

svm_precision = []
svm_recall = []
svm_f = []
acc = []
ps_vectors = []
ns_vectors = []
tr_pos = []
tr_neg = []
te_pos = []
te_neg = []
true_pos = []
true_neg = []
false_pos = []
false_neg = []



for seed in seeds:
    X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=seed)

    w = weight(y_train)
    yTrFreq = scipy.stats.itemfreq(y_train)
    tr_pos = np.append(tr_pos, yTrFreq[1][1])
    tr_neg = np.append(tr_neg, yTrFreq[0][1])

    # print(yTrFreq)



    yTrFreq = scipy.stats.itemfreq(y_test)
    te_pos = np.append(te_pos, yTrFreq[1][1])
    te_neg = np.append(te_neg, yTrFreq[0][1])

    #print(yTrFreq)

    print ("Fitting for Seed = %d" % seed)  

    clf.fit(X_train, y_train, sample_weight = w)
    pred = clf.predict(X_test)

        

    s_vector = clf.n_support_
    s_prec = metrics.precision_score(y_test, pred)#, sample_weight=wt)
    s_recall = metrics.recall_score(y_test, pred)#, sample_weight=wt)
    s_f1 = metrics.f1_score(y_test, pred)#, sample_weight=wt)
    acc_s = metrics.accuracy_score(y_test, pred)
    
    print (metrics.confusion_matrix(y_test, pred))
    true_neg.append(metrics.confusion_matrix(y_test, pred)[0,0])
    true_pos.append(metrics.confusion_matrix(y_test, pred)[1,1])
    false_neg.append(metrics.confusion_matrix(y_test, pred)[1, 0])
    false_pos.append(metrics.confusion_matrix(y_test, pred)[0, 1])
        

    svm_precision.append(s_prec)
    svm_recall.append(s_recall)
    svm_f.append(s_f1)
    acc.append(acc_s)
    ps_vectors = np.append(ps_vectors, s_vector[1])
    ns_vectors = np.append(ns_vectors, s_vector[0])

print ("SVM Cross validation results: ")
print ("Mean Precision: %.2f +/- %.2f "%(np.mean(svm_precision), np.std(svm_precision)))
print ("  Mean  Recall: %.2f +/- %.2f" %(np.mean(svm_recall), np.std(svm_recall)))
print ("      Mean  F1: %.2f +/- %.2f" %(np.mean(svm_f), np.std(svm_f)))
print ("Mean  Accuracy: %.2f +/- %.2f" %(np.mean(acc), np.std(acc)))
print (" True Negative: ", true_neg)
print ("False Negative: ", false_neg)
print (" True Positive: ", true_pos)
print ("False Positive: ", false_pos)
print ("Negative support Vectors: ", ns_vectors)
print ("Positive support Vectors: ", ps_vectors)
print ("Mean positive support vectors: %.2f +/- %.2f"%(np.mean(ps_vectors), np.std(ps_vectors)))
print ("Mean Negative support vectors: %.2f +/- %.2f"%(np.mean(ns_vectors), np.std(ns_vectors)))
print ("Train positive: %.2f" %(np.mean(tr_pos)))
print ("Train negattive: %.2f" %(np.mean(tr_neg)))
print ("Test positive: %.2f" %(np.mean(te_pos)))
print ("Test negative: %.2f" %(np.mean(te_neg)))
# Out:
# Fitting for Seed = 35
# [[ 14 276]
#  [  1  66]]
# Fitting for Seed = 71
# [[ 63 226]
#  [  3  65]]
# Fitting for Seed = 21
# [[ 69 231]
#  [  1  56]]
# Fitting for Seed = 61
# [[ 57 253]
#  [  1  46]]
# Fitting for Seed = 55
# [[  5 292]
#  [  0  60]]
# SVM Cross validation results:
# Mean Precision: 0.19 +/- 0.02
#   Mean  Recall: 0.98 +/- 0.01
#       Mean  F1: 0.31 +/- 0.03
# Mean  Accuracy: 0.28 +/- 0.07
# (' True Negative: ', [14, 63, 69, 57, 5])
# ('False Negative: ', [1, 3, 1, 1, 0])
# (' True Positive: ', [66, 65, 56, 46, 60])
# ('False Positive: ', [276, 226, 231, 253, 292])
# ('Negative support Vectors: ', array([ 697.,  679.,  681.,  669.,  690.]))
# ('Positive support Vectors: ', array([ 54.,  51.,  55.,  57.,  55.]))
# Mean positive support vectors: 54.40 +/- 1.96
# Mean Negative support vectors: 683.20 +/- 9.60
# Train positive: 143.20
# Train negattive: 689.80
# Test positive: 59.80
# Test negative: 297.20

# %%
##  based on this SciKitLearn example:
# http://scikit-learn.org/stable/auto_examples/text/document_classification_20newsgroups.html

# options
print_report = True
print_cm = True
print_top10 = True
n_features = 2 ** 16
filtered = True

########
# Load some categories from the training set

#RANDOM_STATE = 55

sw_train = weight(y_train)
#sw_test = weight(y_test)

categories = ['Irrelevant', 'Relevant']
print('Training and test datasets created')

def trim(s):
    """Trim string to fit on terminal (assuming 80-column display)"""
    return s if len(s) <= 80 else s[:77] + "..."


########
# Benchmark the classifiers, one at a time
def benchmark(clf, name):
    """
    clf - the classifier
    name - its name
    
    benchmark: to create the benchmark metrics for the classification
    returns: the inputs to the results list
    """
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    try:
        clf.fit(X_train, y_train, sample_weight = sw_train)#with weight
    except:
        clf.fit(X_train, y_train)#no weight
        
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    pred = clf.predict(X_test)
    test_time = time() - t0
    print("test time:  %0.3fs" % test_time)
    
    
    acc_score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % acc_score)
    
    prec_score = metrics.precision_score(y_test, pred)
    print("precision:  %0.3f" % prec_score)
    
    recall = metrics.recall_score(y_test, pred)
    print("recall:     %0.3f" % recall)
    
    # get the decision boundary or the probas.
    if hasattr(clf, "decision_function"):
        y_score = np.array(clf.decision_function(X_test))
    else:
        y_score = clf.predict_proba(X_test)[:,1]
        
    if hasattr(clf, "n_support_"):
        print ("Complexity: ", clf.n_support_)

    auc_score = metrics.roc_auc_score(y_test, y_score)
    print("*** AUC for ROC = %0.3f\n" % auc_score)
    
    #if hasattr(clf, 'coef_'):
    #    print("dimensionality: %d" % clf.coef_.shape[1])
    #    print("density: %f" % density(clf.coef_))
    #    print()

    if print_report:
        print("classification report:")
        print(metrics.classification_report(y_test, pred, target_names=categories))

    if print_cm:
        print("confusion matrix:")
        print(metrics.confusion_matrix(y_test, pred))

    print()
    clf_descr = str(clf).split('(')[0]
    return name, acc_score, auc_score, prec_score, recall, train_time, test_time

def create_results():
    """
    create_results: to run the classification and create the of results 
    from the battery of classifiers
    returns: an multiD list of results
    """
    results = []
    for clf, name in (
            (SVC(kernel="linear", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1.0"),
            (SVC(kernel="linear", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10.0"),
            (SVC(kernel="linear", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=100"),
            (SVC(kernel="linear", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000"),
            (SVC(kernel="linear", C=10000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10000"),
            (SVC(kernel="rbf", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=1"),
            (SVC(kernel="rbf", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=10"),
            (SVC(kernel="rbf", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=100"),
            (SVC(kernel="rbf", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000"),
            (SVC(kernel="rbf", C=10000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10000"),
            ):
        print('=' * 80)
        print(name)
        results.append(benchmark(clf, name))

    for penalty in ["l2", "l1"]:
        print('=' * 80)
        print("%s penalty" % penalty.upper())
        # Train Liblinear model
        results.append(benchmark(LinearSVC(loss='l2', penalty=penalty,
                                                dual=False, tol=1e-3, random_state=RANDOM_STATE, class_weight = 'balanced'), "Linear SVC %s penalty" %penalty))


        # Train SGD model
        results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                               penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD classifier %s penalty" %penalty))
        results.append(benchmark(SGDClassifier(loss="hinge", alpha=.0001, n_iter=50,
                                       penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD hinge loss %s penalty" %penalty))
        results.append(benchmark(SGDClassifier(loss="log", alpha=.0001, n_iter=50,
                                   penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD log loss %s penalty" %penalty))
    return results

def comparison_plots(results):
    """
    results - array containing the results from the classification to plot
    
    yields: prints out the results from each classifier and then finishes with plots of the 
    accuracy scores and ROC AUC scores for all the classifiers
    """
    # Train SGD with Elastic Net penalty
    print('=' * 80)
    print("Elastic-Net penalty")
    results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                           penalty="elasticnet", random_state=RANDOM_STATE, class_weight = 'balanced'),"Elastic-Net penalty"))

    # Train sparse Naive Bayes classifiers
    #print('=' * 80)
    #print("Naive Bayes")
    #results.append(benchmark(MultinomialNB(alpha=.01),"Multinomial Naive Bayes"))
    #results.append(benchmark(BernoulliNB(alpha=.01),"Bernouilli Naive Bayes"))

    #print('=' * 80)
    #print("LinearSVC with L1-based feature selection")
    # The smaller C, the stronger the regularization.
    # The more regularization, the more sparsity.
    #results.append(benchmark(Pipeline([
    #  ('feature_selection', LinearSVC(penalty="l1", dual=False, tol=1e-3, random_state=RANDOM_STATE, class_weight = 'balanced')),
    #  ('classification', LinearSVC())
    #            ]),"LinearSVC - L1 feature selection"))

    ######
    # make some plots

    indices = np.arange(len(results))

    results = [[x[i] for x in results] for i in range(7)]

    clf_names, acc_score, auc_score, prec_score, recall, training_time, test_time = results
    training_time = np.array(training_time) / np.max(training_time)
    test_time = np.array(test_time) / np.max(test_time)

    ######
    #  Make a plot for the accuracy scores 
    plt.figure(figsize=(12, 8))
    plt.title("Accuracy Score")
    plt.barh(indices, acc_score, .2, label="accuracy score", color='r')
    plt.barh(indices + .3, training_time, .2, label="training time", color='g')
    plt.barh(indices + .6, test_time, .2, label="test time", color='b')
    plt.yticks(())
    plt.legend(loc='best')
    plt.subplots_adjust(left=.25)
    plt.subplots_adjust(top=.95)
    plt.subplots_adjust(bottom=.05)
    legend = plt.legend(loc=3,frameon=True,framealpha=0.7)
    rect = legend.get_frame()
    rect.set_facecolor('lightgray')
    rect.set_linewidth(0.2)
    plt.gca().xaxis.grid(True)
    #remove_border()

    for i, c in zip(indices, clf_names):
        plt.text(-.3, i, c)

    plt.show()
    
    ######
    #  Make a plot for the ROC curve AUC scores 
    plt.figure(figsize=(12, 8))
    plt.title("ROC curve AUC Score")
    plt.barh(indices, auc_score, .2, label="AUC score", color='r')
    plt.barh(indices + .3, training_time, .2, label="training time", color='g')
    plt.barh(indices + .6, test_time, .2, label="test time", color='b')
    plt.yticks(())
    plt.legend(loc='best')
    plt.subplots_adjust(left=.25)
    plt.subplots_adjust(top=.95)
    plt.subplots_adjust(bottom=.05)
    legend = plt.legend(loc=3,frameon=True,framealpha=0.7)
    rect = legend.get_frame()
    rect.set_facecolor('lightgray')
    rect.set_linewidth(0.2)
    plt.gca().xaxis.grid(True)
    #remove_border()
    

    for i, c in zip(indices, clf_names):
        plt.text(-.3, i, c)
    plt.show()
# Out:
# Training and test datasets created

# %%
# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# Out:
# ================================================================================
# Linear SVC C=1.0
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 1.451s
# test time:  0.393s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  87]))
# *** AUC for ROC = 0.746
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# Linear SVC C=10.0
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.901s
# test time:  0.301s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  67]))
# *** AUC for ROC = 0.763
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# Linear SVC C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.875s
# test time:  0.318s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  61]))
# *** AUC for ROC = 0.769
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# Linear SVC C=1000
# ________________________________________________________________________________
# Training:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 1.073s
# test time:  0.298s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  61]))
# *** AUC for ROC = 0.770
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# Linear SVC C=10000
# ________________________________________________________________________________
# Training:
# SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 1.828s
# test time:  0.331s
# accuracy:   0.406
# precision:  0.216
# recall:     0.967
# ('Complexity: ', array([681,  59]))
# *** AUC for ROC = 0.769
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.98      0.29      0.45       297
#    Relevant       0.22      0.97      0.35        60
#
# avg / total       0.85      0.41      0.43       357
#
# confusion matrix:
# [[ 87 210]
#  [  2  58]]
# ()
# ================================================================================
# SVM with RBF kernel C=1
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.877s
# test time:  0.330s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  97]))
# *** AUC for ROC = 0.729
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# SVM with RBF kernel C=10
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.870s
# test time:  0.330s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  85]))
# *** AUC for ROC = 0.766
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# SVM with RBF kernel C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.877s
# test time:  0.341s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  81]))
# *** AUC for ROC = 0.814
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# Linear SVC C=1000
# ________________________________________________________________________________
# Training:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.908s
# test time:  0.301s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  56]))
# *** AUC for ROC = 0.789
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# Linear SVC C=10000
# ________________________________________________________________________________
# Training:
# SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.788s
# test time:  0.292s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# ('Complexity: ', array([690,  51]))
# *** AUC for ROC = 0.776
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=55, tol=0.001, verbose=0)
# train time: 0.080s
# test time:  0.060s
# accuracy:   0.706
# precision:  0.320
# recall:     0.667
# *** AUC for ROC = 0.759
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.91      0.71      0.80       297
#    Relevant       0.32      0.67      0.43        60
#
# avg / total       0.81      0.71      0.74       357
#
# confusion matrix:
# [[212  85]
#  [ 20  40]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.095s
# test time:  0.000s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# *** AUC for ROC = 0.763
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.090s
# test time:  0.000s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# *** AUC for ROC = 0.763
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.100s
# test time:  0.000s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# *** AUC for ROC = 0.769
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=55, tol=0.001, verbose=0)
# train time: 0.036s
# test time:  0.000s
# accuracy:   0.723
# precision:  0.336
# recall:     0.667
# *** AUC for ROC = 0.749
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.92      0.73      0.81       297
#    Relevant       0.34      0.67      0.45        60
#
# avg / total       0.82      0.72      0.75       357
#
# confusion matrix:
# [[218  79]
#  [ 20  40]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.413s
# test time:  0.000s
# accuracy:   0.252
# precision:  0.182
# recall:     0.983
# *** AUC for ROC = 0.768
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.97      0.10      0.19       297
#    Relevant       0.18      0.98      0.31        60
#
# avg / total       0.84      0.25      0.21       357
#
# confusion matrix:
# [[ 31 266]
#  [  1  59]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.470s
# test time:  0.010s
# accuracy:   0.252
# precision:  0.182
# recall:     0.983
# *** AUC for ROC = 0.768
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.97      0.10      0.19       297
#    Relevant       0.18      0.98      0.31        60
#
# avg / total       0.84      0.25      0.21       357
#
# confusion matrix:
# [[ 31 266]
#  [  1  59]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.521s
# test time:  0.010s
# accuracy:   0.171
# precision:  0.169
# recall:     1.000
# *** AUC for ROC = 0.771
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.00      0.01       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.86      0.17      0.05       357
#
# confusion matrix:
# [[  1 296]
#  [  0  60]]
# ()
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=55, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.379s
# test time:  0.002s
# accuracy:   0.168
# precision:  0.168
# recall:     1.000
# *** AUC for ROC = 0.760
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       297
#    Relevant       0.17      1.00      0.29        60
#
# avg / total       0.03      0.17      0.05       357
#
# confusion matrix:
# [[  0 297]
#  [  0  60]]
# ()

# %%
# Function to compute ROC curve and ROC area for each class
# based on the example in SciKitLearn
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html

def plot_ROC_curve(y_test, y_score):
    """
    y_test - truth series, single array
    y_score - prediction series, single array
    
    yields: plot of curve
    The function will plot the ROC curve and an embedded legend with the AUC score.
    """
    sw_test = weight(y_test)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    fpr, tpr, _ = roc_curve(y_test, y_score, sample_weight=sw_test)
    roc_auc = auc(fpr, tpr)
    # Plot all ROC curves
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = {0:0.3f})' .format(roc_auc), linewidth=2)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic curve')
    plt.legend(loc="lower right")
    plt.show()

# Compute Precision-Recall and plot curve
# As above, based on the SciKit Learn example

def plot_PR_curve(y_test, y_score):
    """
    y_test - truth series, single array
    y_score - prediction series, single array
    
    yields: plot of curve
    The function will plot the precision recall curve and an embedded legend with the AUC score.
    """
    sw_test = weight(y_test)
    
    precision = dict()
    recall = dict()
    precision, recall, _ = precision_recall_curve(y_test, y_score, pos_label=1, sample_weight=sw_test)
    
    # Plot Precision-Recall curve for each class
    plt.clf()
    plt.plot(recall, precision, label='Precision-recall curve')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall curve')
    plt.legend(loc="lower right")
    plt.show()

# Convenience function to adjust plot parameters for a clear layout.
target_names = ["Excluded", "Included"]

def show_confusion_matrix(cm):
    """
    cm - confusion matrix parameters as output from confusion_matrix() function
    
    yields: a plot of the confusion matrix with imshow
    Convenience function to adjust confusion matrix plot parameters for a clear layout.
    """
    sw_test = weight(y_test)
    
    plt.figure(figsize=(5, 5))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.binary)
    plt.title('Confusion matrix')
    plt.set_cmap('Blues')
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=60)
    plt.yticks(tick_marks, target_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

def print_stats(clf, x_train, x_test, y_train, y_test):
    """
    clf - classifier
    x_train - matrix of training features
    x_test - matrix of training features
    y_train - array of training labels
    y_test - array of validation truths
    yields: print outs of the full suite of metrics for the classification for both training and validation sets
    """
    print(clf)
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_train)

    print("Number of mislabeled points out of a total %d training points : %d"
          % (x_train.shape[0],(y_train != y_pred).sum()))
    # Output the hit-rate and the confusion matrix for the training set
    print(("The hit rate on the training set: ", clf.score(x_train, y_train)), '\n')
    scores1 = cross_val_score(clf, x_train, y_train, cv=2, scoring = 'accuracy' , n_jobs = 1)
    scores2 = cross_val_score(clf, x_train, y_train, cv=2, scoring = 'f1' , n_jobs = 1)
    report = precision_recall_fscore_support(y_train, y_pred, average='macro')
    acc_score = accuracy_score(y_train, y_pred)#, sample_weight=sw_test)
    cm = confusion_matrix(y_pred, y_train)

    print("\nprecision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f\n" % 
          (report[0], report[1], report[2], acc_score))
    print("\n10-fold CV mean accuracy = %0.3f, mean F1 = %0.3f\n" % 
          (scores1.mean(), scores2.mean()))
    print(pd.DataFrame(cm.astype(np.float64) / cm.sum(axis=1)),"\n")
    print("The confusion matrix on the training set: \n",pd.DataFrame(cm) )
    show_confusion_matrix(cm)

    pred = clf.predict(x_test)

    print("Number of mislabeled points out of a total %d testing points : %d"
          % (x_test.shape[0],(y_test != pred).sum()))
    # Output the hit-rate and the confusion matrix for the training set
    print(("The hit rate on the testing set: ", clf.score(x_test, y_test)), '\n')
    report = precision_recall_fscore_support(y_test, pred, average='macro')
    acc_score = accuracy_score(y_test, pred)
    cm = confusion_matrix(pred, y_test)

    print("\nprecision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f\n" % 
          (report[0], report[1], report[2], acc_score))
    print(pd.DataFrame(cm.astype(np.float64) / cm.sum(axis=1)),"\n")
    print("The confusion matrix on the testing set: \n",pd.DataFrame(cm))
    show_confusion_matrix(cm)

# %%
#RANDOM_STATE = 55


def run_class(X, y, TEST_SIZE):
    """
    X - input matrix of features for the classification
    y - array of truths for the classification 
    TEST_SIZE - number or proportion to use for the test set - int is number, float is precentage
    
    yields: this version runs a battery of classifiers. For each of them, it  
    prints out the performance metrics for the classification and plots the ROC and PR curves
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)    
    
    sw_test = weight(y_test)
    
    for clf, name in (
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced'), "Perceptron50"),
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced', penalty = 'l1'), "Perceptron50l1"),
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced', penalty="l2"), "Perceptron50l2"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced'), "Perceptron20"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced', penalty = 'l1'), "Perceptron20l1"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced', penalty="l2"), "Perceptron20l2"),
            (linear_model.LogisticRegression(C=1e2, random_state=RANDOM_STATE, class_weight='balanced'), "Logistic Regression 1e2"),
            (linear_model.LogisticRegression(C=1e6, random_state=RANDOM_STATE, class_weight='balanced'), "Logistic Regression 1e6"),
            (LinearSVC(C = 1.0, penalty="l2", multi_class = 'crammer_singer', random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC1 L2 penalty"), 
            (LinearSVC(C = 1000, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC1000 L2 penalty"),
            (LinearSVC(C = 100, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC100 L2 penalty"),
            (LinearSVC(C = 1.0, penalty="l1", multi_class = 'crammer_singer', random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC1 L1 penalty"), 
            (LinearSVC(C = 1000, penalty="l1", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC1000 L1 penalty"),
            (LinearSVC(C = 100, penalty="l1", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC100 L1 penalty"),
            (SVC(kernel="linear", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1.0"),
            (SVC(kernel="linear", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10.0"),
            (SVC(kernel="linear", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=100.0"),
            (SVC(kernel="linear", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000.0"),
            (SVC(kernel="rbf", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=1"),
            (SVC(kernel="rbf", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=10"),
            (SVC(kernel="rbf", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=100"),
            (MLPClassifier(hidden_layer_sizes=(5, 5), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(10, 10), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(20, 20), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(5, 5), learning_rate='invscaling', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            ):
        
        print("\n", name, "\ntest size is %d %%  " % (TEST_SIZE*100))

        clf.fit(X_train, y_train)
        print (clf.score(X_test, y_test))
        
        mean_acc_score = clf.score(X_test, y_test)
        pred = clf.predict(X_test)

        report = precision_recall_fscore_support(y_test, pred, average='binary', sample_weight=sw_test)
        acc_score = accuracy_score(y_test, pred)
        cm = confusion_matrix(pred, y_test)

        # get the decision boundary or the probas.
        if hasattr(clf, "decision_function"):
            y_score = np.array(clf.decision_function(X_test))
        else:
            y_score = clf.predict_proba(X_test)[:,1]

        auc_score = metrics.roc_auc_score(y_test, y_score, sample_weight=sw_test)

        #print("mean_accuracy = %0.3f" % mean_acc_score)
        print("precision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f" % 
              (report[0], report[1], report[2], acc_score))
        print("The confusion matrix on the testing set:          \n", pd.DataFrame(cm))
        print("*********** AUC for ROC = %0.3f" % auc_score)
                
        plot_ROC_curve(y_test, y_score)
        plot_PR_curve(y_test, y_score)
        #print (y_score[:,:30])

# %%
# Set the parameters by cross-validation
tuned_parameters = tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'class_weight':['balanced', None],
                     'random_state':[55, 21, 71, 35, 61],
                     'C': [1, 10, 100, 1000]},
                    
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000], 'class_weight':['balanced', None],
                     'random_state':[55, 21, 71, 35, 61],}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# ()
# Best parameters set found on development set:
# ()
# {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.250 (+/-0.328) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.570 (+/-0.013) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.570 (+/-0.013) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.570 (+/-0.013) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.570 (+/-0.013) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.570 (+/-0.013) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.563 (+/-0.034) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.563 (+/-0.034) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.563 (+/-0.034) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.563 (+/-0.034) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.563 (+/-0.034) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.568 (+/-0.009) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.568 (+/-0.009) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.568 (+/-0.009) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.568 (+/-0.009) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.568 (+/-0.009) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.563 (+/-0.030) for {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': 'balanced'}
# 0.563 (+/-0.030) for {'kernel': 'linear', 'C': 1, 'random_state': 21, 'class_weight': 'balanced'}
# 0.563 (+/-0.030) for {'kernel': 'linear', 'C': 1, 'random_state': 71, 'class_weight': 'balanced'}
# 0.563 (+/-0.030) for {'kernel': 'linear', 'C': 1, 'random_state': 35, 'class_weight': 'balanced'}
# 0.563 (+/-0.030) for {'kernel': 'linear', 'C': 1, 'random_state': 61, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1, 'random_state': 21, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1, 'random_state': 71, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1, 'random_state': 35, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1, 'random_state': 61, 'class_weight': None}
# 0.579 (+/-0.018) for {'kernel': 'linear', 'C': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.579 (+/-0.018) for {'kernel': 'linear', 'C': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.579 (+/-0.018) for {'kernel': 'linear', 'C': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.579 (+/-0.018) for {'kernel': 'linear', 'C': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.579 (+/-0.018) for {'kernel': 'linear', 'C': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 10, 'random_state': 55, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 10, 'random_state': 21, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 10, 'random_state': 71, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 10, 'random_state': 35, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 10, 'random_state': 61, 'class_weight': None}
# 0.587 (+/-0.039) for {'kernel': 'linear', 'C': 100, 'random_state': 55, 'class_weight': 'balanced'}
# 0.587 (+/-0.039) for {'kernel': 'linear', 'C': 100, 'random_state': 21, 'class_weight': 'balanced'}
# 0.587 (+/-0.039) for {'kernel': 'linear', 'C': 100, 'random_state': 71, 'class_weight': 'balanced'}
# 0.587 (+/-0.039) for {'kernel': 'linear', 'C': 100, 'random_state': 35, 'class_weight': 'balanced'}
# 0.587 (+/-0.039) for {'kernel': 'linear', 'C': 100, 'random_state': 61, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 100, 'random_state': 55, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 100, 'random_state': 21, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 100, 'random_state': 71, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 100, 'random_state': 35, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 100, 'random_state': 61, 'class_weight': None}
# 0.592 (+/-0.024) for {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# 0.592 (+/-0.024) for {'kernel': 'linear', 'C': 1000, 'random_state': 21, 'class_weight': 'balanced'}
# 0.592 (+/-0.024) for {'kernel': 'linear', 'C': 1000, 'random_state': 71, 'class_weight': 'balanced'}
# 0.592 (+/-0.024) for {'kernel': 'linear', 'C': 1000, 'random_state': 35, 'class_weight': 'balanced'}
# 0.592 (+/-0.024) for {'kernel': 'linear', 'C': 1000, 'random_state': 61, 'class_weight': 'balanced'}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1000, 'random_state': 21, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1000, 'random_state': 71, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1000, 'random_state': 35, 'class_weight': None}
# 0.414 (+/-0.001) for {'kernel': 'linear', 'C': 1000, 'random_state': 61, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.93      0.72      0.81       297
#           1       0.34      0.73      0.47        60
#
# avg / total       0.83      0.72      0.75       357
#
# ()
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.623 (+/-0.021) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.623 (+/-0.021) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.623 (+/-0.021) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.623 (+/-0.021) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.623 (+/-0.021) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.609 (+/-0.062) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.609 (+/-0.062) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.609 (+/-0.062) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.609 (+/-0.062) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.609 (+/-0.062) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.619 (+/-0.014) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.619 (+/-0.014) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.619 (+/-0.014) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.619 (+/-0.014) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.619 (+/-0.014) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.610 (+/-0.051) for {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': 'balanced'}
# 0.610 (+/-0.051) for {'kernel': 'linear', 'C': 1, 'random_state': 21, 'class_weight': 'balanced'}
# 0.610 (+/-0.051) for {'kernel': 'linear', 'C': 1, 'random_state': 71, 'class_weight': 'balanced'}
# 0.610 (+/-0.051) for {'kernel': 'linear', 'C': 1, 'random_state': 35, 'class_weight': 'balanced'}
# 0.610 (+/-0.051) for {'kernel': 'linear', 'C': 1, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 61, 'class_weight': None}
# 0.632 (+/-0.035) for {'kernel': 'linear', 'C': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.632 (+/-0.035) for {'kernel': 'linear', 'C': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.632 (+/-0.035) for {'kernel': 'linear', 'C': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.632 (+/-0.035) for {'kernel': 'linear', 'C': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.632 (+/-0.035) for {'kernel': 'linear', 'C': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 61, 'class_weight': None}
# 0.642 (+/-0.073) for {'kernel': 'linear', 'C': 100, 'random_state': 55, 'class_weight': 'balanced'}
# 0.642 (+/-0.073) for {'kernel': 'linear', 'C': 100, 'random_state': 21, 'class_weight': 'balanced'}
# 0.642 (+/-0.073) for {'kernel': 'linear', 'C': 100, 'random_state': 71, 'class_weight': 'balanced'}
# 0.642 (+/-0.073) for {'kernel': 'linear', 'C': 100, 'random_state': 35, 'class_weight': 'balanced'}
# 0.642 (+/-0.073) for {'kernel': 'linear', 'C': 100, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 61, 'class_weight': None}
# 0.648 (+/-0.051) for {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# 0.648 (+/-0.051) for {'kernel': 'linear', 'C': 1000, 'random_state': 21, 'class_weight': 'balanced'}
# 0.648 (+/-0.051) for {'kernel': 'linear', 'C': 1000, 'random_state': 71, 'class_weight': 'balanced'}
# 0.648 (+/-0.051) for {'kernel': 'linear', 'C': 1000, 'random_state': 35, 'class_weight': 'balanced'}
# 0.648 (+/-0.051) for {'kernel': 'linear', 'C': 1000, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 61, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       0.93      0.72      0.81       297
#           1       0.34      0.73      0.47        60
#
# avg / total       0.83      0.72      0.75       357
#
# ()

# %%
# Set the parameters by cross-validation
#linearsvc


tuned_parameters = [{'C': [1.0, 10, 100, 1000],
                     #'penalty': ['l2', 'l1'],
                     'class_weight':['balanced', None],
                     #'loss': ['squared_hinge', 'hinge'],
                     'random_state':[55, 21, 71, 35, 61],
                     #'dual': [True, False],
                     'multi_class': ['crammer_singer', 'ovr']
                     }]

                    
scores = ['recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(LinearSVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for recall
# ()
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-15-ee0bf4a628b1> in <module>()
#      20
#      21     clf = GridSearchCV(LinearSVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
# ---> 22     clf.fit(X_train, y_train)
#      23
#      24     print("Best parameters set found on development set:")
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\model_selection\_search.pyc in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\model_selection\_search.pyc in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# --> 564           for parameters in parameter_iterable
#     565           for train, test in cv_iter)
#     566
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\externals\joblib\_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\externals\joblib\_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\model_selection\_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\svm\classes.pyc in fit(self, X, y, sample_weight)
#     213             self.class_weight, self.penalty, self.dual, self.verbose,
#     214             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 215             self.loss, sample_weight=sample_weight)
#     216
#     217         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# C:\Users\CR107\Anaconda2\lib\site-packages\sklearn\svm\base.pyc in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     910         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     911         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 912         epsilon, sample_weight)
#     913     # Regarding rnd.randint(..) in the above signature:
#     914     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
# Set the parameters by cross-validation
#PERCEPTRON
tuned_parameters = [{'n_iter': [2, 5, 10,50],
                     'penalty': [None, 'l2', 'l1', 'elasticnet'],
                     'random_state':[55, 21, 71, 35, 61],
                     'alpha': [0.001, 0.0001, 0.00001],
                     'class_weight':['balanced', None]
                    }]

scores = ['recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(Perceptron(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()

# %%
##run 2

# %%
RANDOM_STATE = 61
X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)
# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)
# Out:
# ================================================================================
# Perceptron50
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty=None,
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.090s
# test time:  0.003s
# accuracy:   0.147
# precision:  0.145
# recall:     1.000
# *** AUC for ROC = 0.705
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.00      0.00       407
#    Relevant       0.15      1.00      0.25        69
#
# avg / total       0.88      0.15      0.04       476
#
# confusion matrix:
# [[  1 406]
#  [  0  69]]
# ()
# ================================================================================
# Perceptron50l1
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty='l1',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.407s
# test time:  0.002s
# accuracy:   0.145
# precision:  0.145
# recall:     1.000
# *** AUC for ROC = 0.693
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       407
#    Relevant       0.14      1.00      0.25        69
#
# avg / total       0.02      0.14      0.04       476
#
# confusion matrix:
# [[  0 407]
#  [  0  69]]
# ()
# ================================================================================
# Perceptron50l2
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty='l2',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.097s
# test time:  0.002s
# accuracy:   0.145
# precision:  0.145
# recall:     1.000
# *** AUC for ROC = 0.696
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       407
#    Relevant       0.14      1.00      0.25        69
#
# avg / total       0.02      0.14      0.04       476
#
# confusion matrix:
# [[  0 407]
#  [  0  69]]
# ()
# ================================================================================
# Perceptron20
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty=None,
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.041s
# test time:  0.002s
# accuracy:   0.355
# precision:  0.164
# recall:     0.841
# *** AUC for ROC = 0.675
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.91      0.27      0.42       407
#    Relevant       0.16      0.84      0.27        69
#
# avg / total       0.80      0.36      0.40       476
#
# confusion matrix:
# [[111 296]
#  [ 11  58]]
# ()
# ================================================================================
# Perceptron20l1
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty='l1',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.176s
# test time:  0.011s
# accuracy:   0.319
# precision:  0.167
# recall:     0.928
# *** AUC for ROC = 0.676
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.95      0.22      0.35       407
#    Relevant       0.17      0.93      0.28        69
#
# avg / total       0.83      0.32      0.34       476
#
# confusion matrix:
# [[ 88 319]
#  [  5  64]]
# ()
# ================================================================================
# Perceptron20l2
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty='l2',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.036s
# test time:  0.046s
# accuracy:   0.395
# precision:  0.165
# recall:     0.783
# *** AUC for ROC = 0.669
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.90      0.33      0.48       407
#    Relevant       0.17      0.78      0.27        69
#
# avg / total       0.79      0.39      0.45       476
#
# confusion matrix:
# [[134 273]
#  [ 15  54]]
# ()
# ================================================================================
# Logistic Regression 1e2
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=100.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=61,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# train time: 0.307s
# test time:  0.002s
# accuracy:   0.655
# precision:  0.243
# recall:     0.652
# *** AUC for ROC = 0.708
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.92      0.66      0.77       407
#    Relevant       0.24      0.65      0.35        69
#
# avg / total       0.82      0.66      0.71       476
#
# confusion matrix:
# [[267 140]
#  [ 24  45]]
# ()
# ================================================================================
# Logistic Regression 1e6
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=1000000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=61,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# train time: 4.512s
# test time:  0.003s
# accuracy:   0.779
# precision:  0.357
# recall:     0.652
# *** AUC for ROC = 0.824
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.93      0.80      0.86       407
#    Relevant       0.36      0.65      0.46        69
#
# avg / total       0.85      0.78      0.80       476
#
# confusion matrix:
# [[326  81]
#  [ 24  45]]
# ()
# ================================================================================
# Linear SVC C=0.025
# ________________________________________________________________________________
# Training:
# SVC(C=0.025, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.757s
# test time:  0.490s
# accuracy:   0.145
# precision:  0.145
# recall:     1.000
# ('Complexity: ', array([580, 112]))
# *** AUC for ROC = 0.631
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       407
#    Relevant       0.14      1.00      0.25        69
#
# avg / total       0.02      0.14      0.04       476
#
# confusion matrix:
# [[  0 407]
#  [  0  69]]
# ()
# ================================================================================
# Linear SVC C=1.05
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.705s
# test time:  0.426s
# accuracy:   0.582
# precision:  0.207
# recall:     0.667
# ('Complexity: ', array([511, 101]))
# *** AUC for ROC = 0.660
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.91      0.57      0.70       407
#    Relevant       0.21      0.67      0.32        69
#
# avg / total       0.81      0.58      0.64       476
#
# confusion matrix:
# [[231 176]
#  [ 23  46]]
# ()
# ================================================================================
# Linear SVC L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=61, tol=0.0001,
#      verbose=0)
# train time: 0.182s
# test time:  0.012s
# accuracy:   0.674
# precision:  0.235
# recall:     0.551
# *** AUC for ROC = 0.685
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.90      0.70      0.79       407
#    Relevant       0.23      0.55      0.33        69
#
# avg / total       0.80      0.67      0.72       476
#
# confusion matrix:
# [[283 124]
#  [ 31  38]]
# ()
# ================================================================================
# SVM with RBF kernel C=1
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.908s
# test time:  0.648s
# accuracy:   0.145
# precision:  0.145
# recall:     1.000
# ('Complexity: ', array([580, 112]))
# *** AUC for ROC = 0.630
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       407
#    Relevant       0.14      1.00      0.25        69
#
# avg / total       0.02      0.14      0.04       476
#
# confusion matrix:
# [[  0 407]
#  [  0  69]]
# ()
# ================================================================================
# SVM with RBF kernel C=10
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.792s
# test time:  0.509s
# accuracy:   0.145
# precision:  0.145
# recall:     1.000
# ('Complexity: ', array([580, 112]))
# *** AUC for ROC = 0.631
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.00      0.00      0.00       407
#    Relevant       0.14      1.00      0.25        69
#
# avg / total       0.02      0.14      0.04       476
#
# confusion matrix:
# [[  0 407]
#  [  0  69]]
# ()
# ================================================================================
# SVM with RBF kernel C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.787s
# test time:  0.477s
# accuracy:   0.542
# precision:  0.208
# recall:     0.768
# ('Complexity: ', array([559, 109]))
# *** AUC for ROC = 0.637
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.93      0.50      0.65       407
#    Relevant       0.21      0.77      0.33        69
#
# avg / total       0.82      0.54      0.61       476
#
# confusion matrix:
# [[205 202]
#  [ 16  53]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 85.711s
# test time:  0.108s
# accuracy:   0.855
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.500
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      1.00      0.92       407
#    Relevant       0.00      0.00      0.00        69
#
# avg / total       0.73      0.86      0.79       476
#
# confusion matrix:
# [[407   0]
#  [ 69   0]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10, 10), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 43.510s
# test time:  0.045s
# accuracy:   0.855
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.679
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      1.00      0.92       407
#    Relevant       0.00      0.00      0.00        69
#
# avg / total       0.73      0.86      0.79       476
#
# confusion matrix:
# [[407   0]
#  [ 69   0]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 76.285s
# test time:  0.002s
# accuracy:   0.861
# precision:  0.600
# recall:     0.130
# *** AUC for ROC = 0.712
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.87      0.99      0.92       407
#    Relevant       0.60      0.13      0.21        69
#
# avg / total       0.83      0.86      0.82       476
#
# confusion matrix:
# [[401   6]
#  [ 60   9]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5), learning_rate='invscaling',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 85.811s
# test time:  0.003s
# accuracy:   0.855
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.500
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.86      1.00      0.92       407
#    Relevant       0.00      0.00      0.00        69
#
# avg / total       0.73      0.86      0.79       476
#
# confusion matrix:
# [[407   0]
#  [ 69   0]]
# ()
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=61, tol=0.001, verbose=0)
# train time: 0.091s
# test time:  0.002s
# accuracy:   0.674
# precision:  0.235
# recall:     0.551
# *** AUC for ROC = 0.685
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.90      0.70      0.79       407
#    Relevant       0.23      0.55      0.33        69
#
# avg / total       0.80      0.67      0.72       476
#
# confusion matrix:
# [[283 124]
#  [ 31  38]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.092s
# test time:  0.022s
# accuracy:   0.246
# precision:  0.160
# recall:     0.986
# *** AUC for ROC = 0.687
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.98      0.12      0.21       407
#    Relevant       0.16      0.99      0.27        69
#
# avg / total       0.86      0.25      0.22       476
#
# confusion matrix:
# [[ 49 358]
#  [  1  68]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.091s
# test time:  0.002s
# accuracy:   0.246
# precision:  0.160
# recall:     0.986
# *** AUC for ROC = 0.687
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.98      0.12      0.21       407
#    Relevant       0.16      0.99      0.27        69
#
# avg / total       0.86      0.25      0.22       476
#
# confusion matrix:
# [[ 49 358]
#  [  1  68]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.119s
# test time:  0.010s
# accuracy:   0.305
# precision:  0.164
# recall:     0.928
# *** AUC for ROC = 0.689
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.94      0.20      0.33       407
#    Relevant       0.16      0.93      0.28        69
#
# avg / total       0.83      0.30      0.32       476
#
# confusion matrix:
# [[ 81 326]
#  [  5  64]]
# ()
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=61, tol=0.001, verbose=0)
# train time: 0.053s
# test time:  0.008s
# accuracy:   0.670
# precision:  0.238
# recall:     0.580
# *** AUC for ROC = 0.687
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.91      0.69      0.78       407
#    Relevant       0.24      0.58      0.34        69
#
# avg / total       0.81      0.67      0.72       476
#
# confusion matrix:
# [[279 128]
#  [ 29  40]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.431s
# test time:  0.002s
# accuracy:   0.309
# precision:  0.161
# recall:     0.899
# *** AUC for ROC = 0.688
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.92      0.21      0.34       407
#    Relevant       0.16      0.90      0.27        69
#
# avg / total       0.81      0.31      0.33       476
#
# confusion matrix:
# [[ 85 322]
#  [  7  62]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.426s
# test time:  0.002s
# accuracy:   0.309
# precision:  0.161
# recall:     0.899
# *** AUC for ROC = 0.688
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.92      0.21      0.34       407
#    Relevant       0.16      0.90      0.27        69
#
# avg / total       0.81      0.31      0.33       476
#
# confusion matrix:
# [[ 85 322]
#  [  7  62]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.567s
# test time:  0.002s
# accuracy:   0.370
# precision:  0.169
# recall:     0.855
# *** AUC for ROC = 0.689
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.92      0.29      0.44       407
#    Relevant       0.17      0.86      0.28        69
#
# avg / total       0.81      0.37      0.42       476
#
# confusion matrix:
# [[117 290]
#  [ 10  59]]
# ()
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=61, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.349s
# test time:  0.013s
# accuracy:   0.273
# precision:  0.163
# recall:     0.971
# *** AUC for ROC = 0.687
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.97      0.15      0.27       407
#    Relevant       0.16      0.97      0.28        69
#
# avg / total       0.85      0.27      0.27       476
#
# confusion matrix:
# [[ 63 344]
#  [  2  67]]
# ()
# ('\n', 'Perceptron50', '\ntest size is 40 %  ')
# 0.518907563025
# precision = 0.484, recall = 0.710, F1 = 0.576, accuracy = 0.519
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  198  20
# 1  209  49)
# *********** AUC for ROC = 0.700
# ('\n', 'Perceptron50l1', '\ntest size is 40 %  ')
# 0.653361344538
# precision = 0.557, recall = 0.638, F1 = 0.595, accuracy = 0.653
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  267  25
# 1  140  44)
# *********** AUC for ROC = 0.686
# ('\n', 'Perceptron50l2', '\ntest size is 40 %  ')
# 0.569327731092
# precision = 0.518, recall = 0.725, F1 = 0.604, accuracy = 0.569
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  221  19
# 1  186  50)
# *********** AUC for ROC = 0.699
# ('\n', 'Perceptron20', '\ntest size is 40 %  ')
# 0.170168067227
# precision = 0.402, recall = 0.957, F1 = 0.567, accuracy = 0.170
# ('The confusion matrix on the testing set:          \n',      0   1
# 0   15   3
# 1  392  66)
# *********** AUC for ROC = 0.657
# ('\n', 'Perceptron20l1', '\ntest size is 40 %  ')
# 0.144957983193
# precision = 0.404, recall = 1.000, F1 = 0.576, accuracy = 0.145
# ('The confusion matrix on the testing set:          \n',      0   1
# 0    0   0
# 1  407  69)
# *********** AUC for ROC = 0.667
# ('\n', 'Perceptron20l2', '\ntest size is 40 %  ')
# 0.155462184874
# precision = 0.407, recall = 1.000, F1 = 0.579, accuracy = 0.155
# ('The confusion matrix on the testing set:          \n',      0   1
# 0    5   0
# 1  402  69)
# *********** AUC for ROC = 0.644
# ('\n', 'Logistic Regression 1e2', '\ntest size is 40 %  ')
# 0.703781512605
# precision = 0.592, recall = 0.594, F1 = 0.593, accuracy = 0.704
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  294  28
# 1  113  41)
# *********** AUC for ROC = 0.700
# ('\n', 'Logistic Regression 1e6', '\ntest size is 40 %  ')
# 0.783613445378
# precision = 0.686, recall = 0.594, F1 = 0.637, accuracy = 0.784
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  332  28
# 1   75  41)
# *********** AUC for ROC = 0.806
# ('\n', 'Linear SVC C=0.025', '\ntest size is 40 %  ')
# 0.144957983193
# precision = 0.404, recall = 1.000, F1 = 0.576, accuracy = 0.145
# ('The confusion matrix on the testing set:          \n',      0   1
# 0    0   0
# 1  407  69)
# *********** AUC for ROC = 0.631
# ('\n', 'Linear SVC C=1.05', '\ntest size is 40 %  ')
# 0.613445378151
# precision = 0.512, recall = 0.594, F1 = 0.550, accuracy = 0.613
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  251  28
# 1  156  41)
# *********** AUC for ROC = 0.672
# ('\n', 'Linear SVC L2 penalty', '\ntest size is 40 %  ')
# 0.674369747899
# precision = 0.551, recall = 0.551, F1 = 0.551, accuracy = 0.674
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  283  31
# 1  124  38)
# *********** AUC for ROC = 0.685
# ('\n', 'SVM with RBF kernel C=1', '\ntest size is 40 %  ')
# 0.855042016807
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.855
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  407  69
# 1    0   0)
# *********** AUC for ROC = 0.631
# ('\n', 'SVM with RBF kernel C=10', '\ntest size is 40 %  ')
# 0.855042016807
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.855
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  407  69
# 1    0   0)
# *********** AUC for ROC = 0.631
# ('\n', 'SVM with RBF kernel C=100', '\ntest size is 40 %  ')
# 0.573529411765
# precision = 0.501, recall = 0.652, F1 = 0.567, accuracy = 0.574
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  228  24
# 1  179  45)
# *********** AUC for ROC = 0.641
# ('\n', 'MLP5adaptive', '\ntest size is 40 %  ')
# 0.855042016807
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.855
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  407  69
# 1    0   0)
# *********** AUC for ROC = 0.500
# ('\n', 'MLP5adaptive', '\ntest size is 40 %  ')
# 0.855042016807
# precision = 0.000, recall = 0.000, F1 = 0.000, accuracy = 0.855
# ('The confusion matrix on the testing set:          \n',      0   1
# 0  407  69
# 1    0   0)
# *********** AUC for ROC = 0.679

# %%
#run 3
RANDOM_STATE = 21


X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)

# %%
#run 4
RANDOM_STATE =71


X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)

# %%
#run 5
RANDOM_STATE = 35


X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)
