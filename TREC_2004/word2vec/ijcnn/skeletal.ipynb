# %%
#%run 'word2vec_data.ipynb'
import cPickle as pickle
# %pylab inline

import scipy
import numpy as np
import pandas as pd
#import plotly.plotly as py
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords

from gensim import models


import math
import codecs
import re
import string
from time import time


## Sklearn
from sklearn import svm, datasets
import sklearn

from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, roc_auc_score, accuracy_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score, precision_score
from sklearn.preprocessing import StandardScaler, label_binarize, Imputer, OneHotEncoder
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, BaggingClassifier, RandomTreesEmbedding
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB
from sklearn import linear_model
from sklearn.linear_model import SGDClassifier
from sklearn import datasets, feature_selection, cluster, feature_extraction
from sklearn import neighbors, decomposition, metrics
from sklearn import decomposition, feature_selection, model_selection
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics


from sklearn.pipeline import Pipeline, make_pipeline
from scipy import interp

#############################
### Matplotlib
import matplotlib.pyplot as plt # module for plotting 
from matplotlib import interactive, font_manager
from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D

#############################
### other stuff
from IPython import display

import os
#import ipyparallel as ipp
import warnings
warnings.filterwarnings('ignore')

# This is here to avoid all the Matplotlib warnings due to current bugs 
# - not a good idea to keep around
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline  

print ("Required Libraries loaded.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Required Libraries loaded.

# %%
#!pip install --upgrade version_information
#%reload_ext version_information
# %load_ext version_information 
# %version_information scipy, numpy, sklearn, pandas, scipy, nltk, gensim, matplotlib, os, cpickle
# Out:
# Software versions
# Python 2.7.12 64bit [MSC v.1500 64 bit (AMD64)]
# IPython 5.1.0
# OS Windows 7 6.1.7601 SP1
# scipy 0.18.1
# numpy 1.11.2
# sklearn 0.18.1
# pandas 0.19.1
# scipy 0.18.1
# nltk 3.2.1
# gensim 0.12.4
# matplotlib 1.5.3
# os The 'os' distribution was not found and is required by the application
# cpickle The 'cpickle' distribution was not found and is required by the application
# Tue Jan 24 18:04:34 2017 GMT Standard Time

# %%
inhibitor  = pd.read_csv("C:\EPC_Data\TREC_BROKEN\No_Mh_Tag/skeletalMuscleRelaxants_no_mh.csv", sep=",", index_col = "PMID")

# %%
folder = "C:\Users\CR107\Dropbox\PhD\Experiments\TREC_2004\data\word2vec"
filepath = os.path.join(folder, "skeletalMuscleRelaxants_chi2_features_10minwords_15context")
model = models.Word2Vec.load(filepath)
print ("\nMatrix of word vectors is size : ", model.syn0.shape)
# Out:
# ('\nMatrix of word vectors is size : ', (3075L, 11L))

# %%
#Create feature vectors from the averages of word vectors

def makeFeatureVec(words, model):
    """
    words - list of words (i.e. article) to be used as input for the creation of word vectors
    model - model to use for the creation of the vectors
    
    makeFeatureVec: Function to average all of the word vectors in a given paragraph
    returns: a numpy array of floats that are the average of the constituent word vectors for each word
    """
    num_features = model.syn0.shape[1]
    featureVec = np.zeros((num_features,),dtype="float32")
    nwords = 0.
    # 
    # Index2word is a list that contains the names of the words in 
    # the model's vocabulary. Convert it to a set, for speed 
    index2word_set = set(model.index2word)
    #
    # Loop over each word in the article and, if it is in the model's
    # vocaublary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    # 
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    return featureVec

def getAvgFeatureVecs(articles, model):
    """
    articles - list of articles for which the creation of word vectors needs to be done for each
    model - model to use for the creation of the vectors
    
    getAvgFeatureVecs: Given a set of articles (each one a list of words), calculate 
    the average feature vector for each one and return a 2D numpy array 
    returns: a 2D numpy array that contains the average of the constituent word vectors for each article
    """
    num_features = model.syn0.shape[1]
    articleFeatureVecs = np.zeros((len(articles),num_features),dtype="float32")
    counter = 0.
    
    # Loop through the articles
    for article in articles:
        #
        # Print a status message every 1000th review
        if counter%500. == 0.:
            print ("Article %d of %d" % (counter, len(articles)))
        # 
        # Call the function (defined above) that makes average feature vectors
        articleFeatureVecs[counter] = makeFeatureVec(article, model)
        #
        # Increment the counter
        counter = counter + 1.
    return articleFeatureVecs

# %%
# Import articles for string cleaning

def clean_text(text, stem_words = False, remove_stopwords = False):
    ###clean
    texts = re.sub("[^a-zA-Z]",    #pattern to match
              " ",              #replace other with this
              str(text))                 #text to apply to
         
    #print "Text recived: ", texts 
    clean_corpus = texts.lower().split()
    #print "corpus: ", clean_corpus
    if stem_words:
        # Porter stemmer
        porter = nltk.PorterStemmer()
        # Snowball stemmer
        snowball = nltk.SnowballStemmer('english')
        # Lancaster stemmer
        lancaster = nltk.LancasterStemmer()
        # General stemming Lambda function to stem tokens
        clean_corpus = lambda tokens: [porter.stem(w) for w in corpus]
    if remove_stopwords:   # Optionally remove stop words
        stops = set(stopwords.words("english"))
        clean_corpus = [w for w in clean_corpus if not w in stops]
        #print "Clean_corpus: ", clean_corpus
    
    return (clean_corpus)

# %%
# ****************************************************************
# Calculate average feature vectors for training and testing sets,
# using the functions we defined above. We remove stopwords.

print ("Creating average feature vecs for articles")
cleaned_articles = []
for article in inhibitor.TIABSMh:
    cleaned_articles.append(clean_text(article, stem_words=False, remove_stopwords=True ))

averageWordVecs = getAvgFeatureVecs(cleaned_articles, model)
# Out:
# Creating average feature vecs for articles
# Article 0 of 1610
# Article 500 of 1610
# Article 1000 of 1610
# Article 1500 of 1610

# %%
RANDOM_STATE = 55
TEST_SIZE = 0.3

X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=37)

print (len(X_train))
print (len(X_test))
# Out:
# 1127
# 483

# %%
yTrFreq = scipy.stats.itemfreq(inhibitor.Label)
print(yTrFreq)
# Out:
# [[   0 1601]
#  [   1    9]]

# %%
def weight(x):
    x = np.where(x==0, 1, 4)
    return x

# %%
clf = SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,decision_function_shape=None, degree=3, 
              gamma='auto', kernel='linear', max_iter=-1, probability=False, random_state=55, shrinking=True,
              tol=0.001, verbose=False)

seeds = [35, 71, 21, 61, 55]

svm_precision = []
svm_recall = []
svm_f = []
acc = []
ps_vectors = []
ns_vectors = []
tr_pos = []
tr_neg = []
te_pos = []
te_neg = []
true_pos = []
true_neg = []
false_pos = []
false_neg = []



for seed in seeds:
    X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=seed)

    w = weight(y_train)
    yTrFreq = scipy.stats.itemfreq(y_train)
    tr_pos = np.append(tr_pos, yTrFreq[1][1])
    tr_neg = np.append(tr_neg, yTrFreq[0][1])

    # print(yTrFreq)



    yTrFreq = scipy.stats.itemfreq(y_test)
    #te_pos = np.append(te_pos, yTrFreq[1][1])
    te_neg = np.append(te_neg, yTrFreq[0][1])

    #print(yTrFreq)

    print ("Fitting for Seed = %d" % seed)  

    clf.fit(X_train, y_train, sample_weight = w)
    pred = clf.predict(X_test)

        

    s_vector = clf.n_support_
    s_prec = metrics.precision_score(y_test, pred)#, sample_weight=wt)
    s_recall = metrics.recall_score(y_test, pred)#, sample_weight=wt)
    s_f1 = metrics.f1_score(y_test, pred)#, sample_weight=wt)
    acc_s = metrics.accuracy_score(y_test, pred)
    
    print (metrics.confusion_matrix(y_test, pred))
    true_neg.append(metrics.confusion_matrix(y_test, pred)[0,0])
    true_pos.append(metrics.confusion_matrix(y_test, pred)[1,1])
    false_neg.append(metrics.confusion_matrix(y_test, pred)[1, 0])
    false_pos.append(metrics.confusion_matrix(y_test, pred)[0, 1])
        

    svm_precision.append(s_prec)
    svm_recall.append(s_recall)
    svm_f.append(s_f1)
    acc.append(acc_s)
    ps_vectors = np.append(ps_vectors, s_vector[1])
    ns_vectors = np.append(ns_vectors, s_vector[0])

print ("SVM Cross validation results: ")
print ("Mean Precision: %.2f +/- %.2f "%(np.mean(svm_precision), np.std(svm_precision)))
print ("  Mean  Recall: %.2f +/- %.2f" %(np.mean(svm_recall), np.std(svm_recall)))
print ("      Mean  F1: %.2f +/- %.2f" %(np.mean(svm_f), np.std(svm_f)))
print ("Mean  Accuracy: %.2f +/- %.2f" %(np.mean(acc), np.std(acc)))
print (" True Negative: ", true_neg)
print ("False Negative: ", false_neg)
print (" True Positive: ", true_pos)
print ("False Positive: ", false_pos)
print ("Negative support Vectors: ", ns_vectors)
print ("Positive support Vectors: ", ps_vectors)
print ("Mean positive support vectors: %.2f +/- %.2f"%(np.mean(ps_vectors), np.std(ps_vectors)))
print ("Mean Negative support vectors: %.2f +/- %.2f"%(np.mean(ns_vectors), np.std(ns_vectors)))
print ("Train positive: %.2f" %(np.mean(tr_pos)))
print ("Train negattive: %.2f" %(np.mean(tr_neg)))
print ("Test positive: %.2f" %(np.mean(te_pos)))
print ("Test negative: %.2f" %(np.mean(te_neg)))
# Out:
# Fitting for Seed = 35
# [[182 301]
#  [  0   0]]
# Fitting for Seed = 71
# [[183 297]
#  [  0   3]]
# Fitting for Seed = 21
# [[230 248]
#  [  3   2]]
# Fitting for Seed = 61
# [[173 310]
#  [  0   0]]
# Fitting for Seed = 55
# [[189 292]
#  [  0   2]]
# SVM Cross validation results:
# Mean Precision: 0.00 +/- 0.00
#   Mean  Recall: 0.48 +/- 0.45
#       Mean  F1: 0.01 +/- 0.01
# Mean  Accuracy: 0.40 +/- 0.04
# (' True Negative: ', [182, 183, 230, 173, 189])
# ('False Negative: ', [0, 0, 3, 0, 0])
# (' True Positive: ', [0, 3, 2, 0, 2])
# ('False Positive: ', [301, 297, 248, 310, 292])
# ('Negative support Vectors: ', array([ 988.,  958.,  863.,  975.,  987.]))
# ('Positive support Vectors: ', array([ 6.,  5.,  4.,  6.,  4.]))
# Mean positive support vectors: 5.00 +/- 0.89
# Mean Negative support vectors: 954.20 +/- 46.87
# Train positive: 7.00
# Train negattive: 1120.00
# Test positive: nan
# Test negative: 481.00

# %%
##  based on this SciKitLearn example:
# http://scikit-learn.org/stable/auto_examples/text/document_classification_20newsgroups.html

# options
print_report = True
print_cm = True
print_top10 = True
n_features = 2 ** 16
filtered = True

########
# Load some categories from the training set

#RANDOM_STATE = 55

sw_train = weight(y_train)
#sw_test = weight(y_test)

categories = ['Irrelevant', 'Relevant']
print('Training and test datasets created')

def trim(s):
    """Trim string to fit on terminal (assuming 80-column display)"""
    return s if len(s) <= 80 else s[:77] + "..."


########
# Benchmark the classifiers, one at a time
def benchmark(clf, name):
    """
    clf - the classifier
    name - its name
    
    benchmark: to create the benchmark metrics for the classification
    returns: the inputs to the results list
    """
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    try:
        clf.fit(X_train, y_train, sample_weight = sw_train)#with weight
    except:
        clf.fit(X_train, y_train)#no weight
        
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    pred = clf.predict(X_test)
    test_time = time() - t0
    print("test time:  %0.3fs" % test_time)
    
    
    acc_score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % acc_score)
    
    prec_score = metrics.precision_score(y_test, pred)
    print("precision:  %0.3f" % prec_score)
    
    recall = metrics.recall_score(y_test, pred)
    print("recall:     %0.3f" % recall)
    
    # get the decision boundary or the probas.
    if hasattr(clf, "decision_function"):
        y_score = np.array(clf.decision_function(X_test))
    else:
        y_score = clf.predict_proba(X_test)[:,1]
        
    if hasattr(clf, "n_support_"):
        print ("Complexity: ", clf.n_support_)

    auc_score = metrics.roc_auc_score(y_test, y_score)
    print("*** AUC for ROC = %0.3f\n" % auc_score)
    
    #if hasattr(clf, 'coef_'):
    #    print("dimensionality: %d" % clf.coef_.shape[1])
    #    print("density: %f" % density(clf.coef_))
    #    print()

    if print_report:
        print("classification report:")
        print(metrics.classification_report(y_test, pred, target_names=categories))

    if print_cm:
        print("confusion matrix:")
        print(metrics.confusion_matrix(y_test, pred))

    print()
    clf_descr = str(clf).split('(')[0]
    return name, acc_score, auc_score, prec_score, recall, train_time, test_time

def create_results():
    """
    create_results: to run the classification and create the of results 
    from the battery of classifiers
    returns: an multiD list of results
    """
    results = []
    for clf, name in (
            (SVC(kernel="linear", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1.0"),
            (SVC(kernel="linear", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10.0"),
            (SVC(kernel="linear", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=100"),
            (SVC(kernel="linear", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000"),
            (SVC(kernel="linear", C=10000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10000"),
            (SVC(kernel="rbf", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=1"),
            (SVC(kernel="rbf", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=10"),
            (SVC(kernel="rbf", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=100"),
            (SVC(kernel="rbf", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000"),
            (SVC(kernel="rbf", C=10000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10000"),
            ):
        print('=' * 80)
        print(name)
        results.append(benchmark(clf, name))

    for penalty in ["l2", "l1"]:
        print('=' * 80)
        print("%s penalty" % penalty.upper())
        # Train Liblinear model
        results.append(benchmark(LinearSVC(loss='l2', penalty=penalty,
                                                dual=False, tol=1e-3, random_state=RANDOM_STATE, class_weight = 'balanced'), "Linear SVC %s penalty" %penalty))


        # Train SGD model
        results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                               penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD classifier %s penalty" %penalty))
        results.append(benchmark(SGDClassifier(loss="hinge", alpha=.0001, n_iter=50,
                                       penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD hinge loss %s penalty" %penalty))
        results.append(benchmark(SGDClassifier(loss="log", alpha=.0001, n_iter=50,
                                   penalty=penalty, random_state=RANDOM_STATE, class_weight = 'balanced'), "SGD log loss %s penalty" %penalty))
    return results

def comparison_plots(results):
    """
    results - array containing the results from the classification to plot
    
    yields: prints out the results from each classifier and then finishes with plots of the 
    accuracy scores and ROC AUC scores for all the classifiers
    """
    # Train SGD with Elastic Net penalty
    print('=' * 80)
    print("Elastic-Net penalty")
    results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                           penalty="elasticnet", random_state=RANDOM_STATE, class_weight = 'balanced'),"Elastic-Net penalty"))

    # Train sparse Naive Bayes classifiers
    #print('=' * 80)
    #print("Naive Bayes")
    #results.append(benchmark(MultinomialNB(alpha=.01),"Multinomial Naive Bayes"))
    #results.append(benchmark(BernoulliNB(alpha=.01),"Bernouilli Naive Bayes"))

    #print('=' * 80)
    #print("LinearSVC with L1-based feature selection")
    # The smaller C, the stronger the regularization.
    # The more regularization, the more sparsity.
    #results.append(benchmark(Pipeline([
    #  ('feature_selection', LinearSVC(penalty="l1", dual=False, tol=1e-3, random_state=RANDOM_STATE, class_weight = 'balanced')),
    #  ('classification', LinearSVC())
    #            ]),"LinearSVC - L1 feature selection"))

    ######
    # make some plots

    indices = np.arange(len(results))

    results = [[x[i] for x in results] for i in range(7)]

    clf_names, acc_score, auc_score, prec_score, recall, training_time, test_time = results
    training_time = np.array(training_time) / np.max(training_time)
    test_time = np.array(test_time) / np.max(test_time)

    ######
    #  Make a plot for the accuracy scores 
    plt.figure(figsize=(12, 8))
    plt.title("Accuracy Score")
    plt.barh(indices, acc_score, .2, label="accuracy score", color='r')
    plt.barh(indices + .3, training_time, .2, label="training time", color='g')
    plt.barh(indices + .6, test_time, .2, label="test time", color='b')
    plt.yticks(())
    plt.legend(loc='best')
    plt.subplots_adjust(left=.25)
    plt.subplots_adjust(top=.95)
    plt.subplots_adjust(bottom=.05)
    legend = plt.legend(loc=3,frameon=True,framealpha=0.7)
    rect = legend.get_frame()
    rect.set_facecolor('lightgray')
    rect.set_linewidth(0.2)
    plt.gca().xaxis.grid(True)
    #remove_border()

    for i, c in zip(indices, clf_names):
        plt.text(-.3, i, c)

    plt.show()
    
    ######
    #  Make a plot for the ROC curve AUC scores 
    plt.figure(figsize=(12, 8))
    plt.title("ROC curve AUC Score")
    plt.barh(indices, auc_score, .2, label="AUC score", color='r')
    plt.barh(indices + .3, training_time, .2, label="training time", color='g')
    plt.barh(indices + .6, test_time, .2, label="test time", color='b')
    plt.yticks(())
    plt.legend(loc='best')
    plt.subplots_adjust(left=.25)
    plt.subplots_adjust(top=.95)
    plt.subplots_adjust(bottom=.05)
    legend = plt.legend(loc=3,frameon=True,framealpha=0.7)
    rect = legend.get_frame()
    rect.set_facecolor('lightgray')
    rect.set_linewidth(0.2)
    plt.gca().xaxis.grid(True)
    #remove_border()
    

    for i, c in zip(indices, clf_names):
        plt.text(-.3, i, c)
    plt.show()
# Out:
# Training and test datasets created

# %%
# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# Out:
# ================================================================================
# Linear SVC C=1.0
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.044s
# test time:  0.006s
# accuracy:   0.395
# precision:  0.007
# recall:     1.000
# ('Complexity: ', array([987,   4]))
# *** AUC for ROC = 0.514
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.39      0.56       481
#    Relevant       0.01      1.00      0.01         2
#
# avg / total       1.00      0.40      0.56       483
#
# confusion matrix:
# [[189 292]
#  [  0   2]]
# ()
# ================================================================================
# Linear SVC C=10.0
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.024s
# test time:  0.004s
# accuracy:   0.578
# precision:  0.005
# recall:     0.500
# ('Complexity: ', array([687,   5]))
# *** AUC for ROC = 0.582
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.58      0.73       481
#    Relevant       0.00      0.50      0.01         2
#
# avg / total       0.99      0.58      0.73       483
#
# confusion matrix:
# [[278 203]
#  [  1   1]]
# ()
# ================================================================================
# Linear SVC C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.020s
# test time:  0.003s
# accuracy:   0.685
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([496,   4]))
# *** AUC for ROC = 0.625
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.69      0.81       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.69      0.81       483
#
# confusion matrix:
# [[331 150]
#  [  2   0]]
# ()
# ================================================================================
# Linear SVC C=1000
# ________________________________________________________________________________
# Training:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.040s
# test time:  0.016s
# accuracy:   0.702
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([404,   5]))
# *** AUC for ROC = 0.632
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.70      0.82       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.70      0.82       483
#
# confusion matrix:
# [[339 142]
#  [  2   0]]
# ()
# ================================================================================
# Linear SVC C=10000
# ________________________________________________________________________________
# Training:
# SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.363s
# test time:  0.000s
# accuracy:   0.720
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([389,   5]))
# *** AUC for ROC = 0.631
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.72      0.84       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.72      0.83       483
#
# confusion matrix:
# [[348 133]
#  [  2   0]]
# ()
# ================================================================================
# SVM with RBF kernel C=1
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.031s
# test time:  0.016s
# accuracy:   0.145
# precision:  0.005
# recall:     1.000
# ('Complexity: ', array([1112,    4]))
# *** AUC for ROC = 0.664
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.14      0.25       481
#    Relevant       0.00      1.00      0.01         2
#
# avg / total       1.00      0.14      0.25       483
#
# confusion matrix:
# [[ 68 413]
#  [  0   2]]
# ()
# ================================================================================
# SVM with RBF kernel C=10
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.032s
# test time:  0.016s
# accuracy:   0.497
# precision:  0.008
# recall:     1.000
# ('Complexity: ', array([892,   5]))
# *** AUC for ROC = 0.544
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.49      0.66       481
#    Relevant       0.01      1.00      0.02         2
#
# avg / total       1.00      0.50      0.66       483
#
# confusion matrix:
# [[238 243]
#  [  0   2]]
# ()
# ================================================================================
# SVM with RBF kernel C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.031s
# test time:  0.000s
# accuracy:   0.704
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([588,   5]))
# *** AUC for ROC = 0.563
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.71      0.83       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.70      0.82       483
#
# confusion matrix:
# [[340 141]
#  [  2   0]]
# ()
# ================================================================================
# Linear SVC C=1000
# ________________________________________________________________________________
# Training:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.027s
# test time:  0.004s
# accuracy:   0.925
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([286,   6]))
# *** AUC for ROC = 0.514
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.93      0.96       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.93      0.96       483
#
# confusion matrix:
# [[447  34]
#  [  2   0]]
# ()
# ================================================================================
# Linear SVC C=10000
# ________________________________________________________________________________
# Training:
# SVC(C=10000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=55, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 0.022s
# test time:  0.000s
# accuracy:   0.969
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([101,   6]))
# *** AUC for ROC = 0.480
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.97      0.98       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.97      0.98       483
#
# confusion matrix:
# [[468  13]
#  [  2   0]]
# ()
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=55, tol=0.001, verbose=0)
# train time: 0.000s
# test time:  0.016s
# accuracy:   0.729
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.582
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.73      0.84       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.73      0.84       483
#
# confusion matrix:
# [[352 129]
#  [  2   0]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.000s
# test time:  0.000s
# accuracy:   0.799
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.666
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.80      0.89       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.80      0.88       483
#
# confusion matrix:
# [[386  95]
#  [  2   0]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.000s
# test time:  0.000s
# accuracy:   0.799
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.666
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.80      0.89       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.80      0.88       483
#
# confusion matrix:
# [[386  95]
#  [  2   0]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.016s
# test time:  0.000s
# accuracy:   0.805
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.621
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.81      0.89       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.81      0.89       483
#
# confusion matrix:
# [[389  92]
#  [  2   0]]
# ()
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=55, tol=0.001, verbose=0)
# train time: 0.017s
# test time:  0.000s
# accuracy:   0.739
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.545
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.74      0.85       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.74      0.85       483
#
# confusion matrix:
# [[357 124]
#  [  2   0]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.000s
# test time:  0.000s
# accuracy:   0.590
# precision:  0.005
# recall:     0.500
# *** AUC for ROC = 0.591
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.59      0.74       481
#    Relevant       0.01      0.50      0.01         2
#
# avg / total       0.99      0.59      0.74       483
#
# confusion matrix:
# [[284 197]
#  [  1   1]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.000s
# test time:  0.000s
# accuracy:   0.590
# precision:  0.005
# recall:     0.500
# *** AUC for ROC = 0.591
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.59      0.74       481
#    Relevant       0.01      0.50      0.01         2
#
# avg / total       0.99      0.59      0.74       483
#
# confusion matrix:
# [[284 197]
#  [  1   1]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=55, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.015s
# test time:  0.000s
# accuracy:   0.592
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.544
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.59      0.74       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.59      0.74       483
#
# confusion matrix:
# [[286 195]
#  [  2   0]]
# ()
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=55, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.000s
# test time:  0.016s
# accuracy:   0.799
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.713
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.80      0.89       481
#    Relevant       0.00      0.00      0.00         2
#
# avg / total       0.99      0.80      0.88       483
#
# confusion matrix:
# [[386  95]
#  [  2   0]]
# ()

# %%
# Function to compute ROC curve and ROC area for each class
# based on the example in SciKitLearn
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html

def plot_ROC_curve(y_test, y_score):
    """
    y_test - truth series, single array
    y_score - prediction series, single array
    
    yields: plot of curve
    The function will plot the ROC curve and an embedded legend with the AUC score.
    """
    sw_test = weight(y_test)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    fpr, tpr, _ = roc_curve(y_test, y_score, sample_weight=sw_test)
    roc_auc = auc(fpr, tpr)
    # Plot all ROC curves
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = {0:0.3f})' .format(roc_auc), linewidth=2)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic curve')
    plt.legend(loc="lower right")
    plt.show()

# Compute Precision-Recall and plot curve
# As above, based on the SciKit Learn example

def plot_PR_curve(y_test, y_score):
    """
    y_test - truth series, single array
    y_score - prediction series, single array
    
    yields: plot of curve
    The function will plot the precision recall curve and an embedded legend with the AUC score.
    """
    sw_test = weight(y_test)
    
    precision = dict()
    recall = dict()
    precision, recall, _ = precision_recall_curve(y_test, y_score, pos_label=1, sample_weight=sw_test)
    
    # Plot Precision-Recall curve for each class
    plt.clf()
    plt.plot(recall, precision, label='Precision-recall curve')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall curve')
    plt.legend(loc="lower right")
    plt.show()

# Convenience function to adjust plot parameters for a clear layout.
target_names = ["Excluded", "Included"]

def show_confusion_matrix(cm):
    """
    cm - confusion matrix parameters as output from confusion_matrix() function
    
    yields: a plot of the confusion matrix with imshow
    Convenience function to adjust confusion matrix plot parameters for a clear layout.
    """
    sw_test = weight(y_test)
    
    plt.figure(figsize=(5, 5))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.binary)
    plt.title('Confusion matrix')
    plt.set_cmap('Blues')
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=60)
    plt.yticks(tick_marks, target_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

def print_stats(clf, x_train, x_test, y_train, y_test):
    """
    clf - classifier
    x_train - matrix of training features
    x_test - matrix of training features
    y_train - array of training labels
    y_test - array of validation truths
    yields: print outs of the full suite of metrics for the classification for both training and validation sets
    """
    print(clf)
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_train)

    print("Number of mislabeled points out of a total %d training points : %d"
          % (x_train.shape[0],(y_train != y_pred).sum()))
    # Output the hit-rate and the confusion matrix for the training set
    print(("The hit rate on the training set: ", clf.score(x_train, y_train)), '\n')
    scores1 = cross_val_score(clf, x_train, y_train, cv=2, scoring = 'accuracy' , n_jobs = 1)
    scores2 = cross_val_score(clf, x_train, y_train, cv=2, scoring = 'f1' , n_jobs = 1)
    report = precision_recall_fscore_support(y_train, y_pred, average='macro')
    acc_score = accuracy_score(y_train, y_pred)#, sample_weight=sw_test)
    cm = confusion_matrix(y_pred, y_train)

    print("\nprecision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f\n" % 
          (report[0], report[1], report[2], acc_score))
    print("\n10-fold CV mean accuracy = %0.3f, mean F1 = %0.3f\n" % 
          (scores1.mean(), scores2.mean()))
    print(pd.DataFrame(cm.astype(np.float64) / cm.sum(axis=1)),"\n")
    print("The confusion matrix on the training set: \n",pd.DataFrame(cm) )
    show_confusion_matrix(cm)

    pred = clf.predict(x_test)

    print("Number of mislabeled points out of a total %d testing points : %d"
          % (x_test.shape[0],(y_test != pred).sum()))
    # Output the hit-rate and the confusion matrix for the training set
    print(("The hit rate on the testing set: ", clf.score(x_test, y_test)), '\n')
    report = precision_recall_fscore_support(y_test, pred, average='macro')
    acc_score = accuracy_score(y_test, pred)
    cm = confusion_matrix(pred, y_test)

    print("\nprecision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f\n" % 
          (report[0], report[1], report[2], acc_score))
    print(pd.DataFrame(cm.astype(np.float64) / cm.sum(axis=1)),"\n")
    print("The confusion matrix on the testing set: \n",pd.DataFrame(cm))
    show_confusion_matrix(cm)

# %%
#RANDOM_STATE = 55


def run_class(X, y, TEST_SIZE):
    """
    X - input matrix of features for the classification
    y - array of truths for the classification 
    TEST_SIZE - number or proportion to use for the test set - int is number, float is precentage
    
    yields: this version runs a battery of classifiers. For each of them, it  
    prints out the performance metrics for the classification and plots the ROC and PR curves
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)    
    
    sw_test = weight(y_test)
    
    for clf, name in (
                        (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced'), "Perceptron50"),
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced', penalty = 'l1'), "Perceptron50l1"),
            (Perceptron(n_iter=50, random_state=RANDOM_STATE, class_weight='balanced', penalty="l2"), "Perceptron50l2"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced'), "Perceptron20"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced', penalty = 'l1'), "Perceptron20l1"),
            (Perceptron(n_iter=20, random_state=RANDOM_STATE, class_weight='balanced', penalty="l2"), "Perceptron20l2"),
            (linear_model.LogisticRegression(C=1e2, random_state=RANDOM_STATE, class_weight='balanced'), "Logistic Regression 1e2"),
            (linear_model.LogisticRegression(C=1e6, random_state=RANDOM_STATE, class_weight='balanced'), "Logistic Regression 1e6"),
            (LinearSVC(C = 1.0, penalty="l2", multi_class = 'crammer_singer', random_state=RANDOM_STATE, class_weight='balanced'), 
             "LinearSVC1 L2 penalty"), 
            (LinearSVC(C = 1000, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC1000 L2 penalty"),
            (LinearSVC(C = 100, penalty="l2", random_state=RANDOM_STATE, class_weight='balanced'), "LinearSVC100 L2 penalty"),
            (LinearSVC(C = 1.0, penalty="l1", multi_class = 'crammer_singer', random_state=RANDOM_STATE, class_weight='balanced'), 
             "LinearSVC1 L1 penalty"), 
            (LinearSVC(C = 1000, penalty="l1", dual = False, random_state=RANDOM_STATE, class_weight='balanced'), 
             "LinearSVC1000 L1 penalty"),
            (LinearSVC(C = 100, penalty="l1", dual = False, random_state=RANDOM_STATE, class_weight='balanced'), 
             "LinearSVC100 L1 penalty"),
            (SVC(kernel="linear", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1.0"),
            (SVC(kernel="linear", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=10.0"),
            (SVC(kernel="linear", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=100.0"),
            (SVC(kernel="linear", C=1000.0, random_state=RANDOM_STATE, class_weight='balanced'), "Linear SVC C=1000.0"),
            
            (SVC(kernel="rbf", C=1.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=1"),
            (SVC(kernel="rbf", C=10.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=10"),
            (SVC(kernel="rbf", C=100.0, random_state=RANDOM_STATE, class_weight='balanced'), "SVM with RBF kernel C=100"),
            (MLPClassifier(hidden_layer_sizes=(5, 5), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(10, 10), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(20, 20), learning_rate='adaptive', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            (MLPClassifier(hidden_layer_sizes=(5, 5), learning_rate='invscaling', learning_rate_init=0.001, power_t=0.5, 
                           max_iter=200, shuffle=True, random_state=RANDOM_STATE, validation_fraction=0.2), "MLP5adaptive"),
            ):
        
        print("\n", name, "\ntest size is %d %%  " % (TEST_SIZE*100))

        clf.fit(X_train, y_train)
        print (clf.score(X_test, y_test))
        
        mean_acc_score = clf.score(X_test, y_test)
        pred = clf.predict(X_test)

        report = precision_recall_fscore_support(y_test, pred, average='binary', sample_weight=sw_test)
        acc_score = accuracy_score(y_test, pred)
        cm = confusion_matrix(pred, y_test)

        # get the decision boundary or the probas.
        if hasattr(clf, "decision_function"):
            y_score = np.array(clf.decision_function(X_test))
        else:
            y_score = clf.predict_proba(X_test)[:,1]

        auc_score = metrics.roc_auc_score(y_test, y_score, sample_weight=sw_test)

        #print("mean_accuracy = %0.3f" % mean_acc_score)
        print("precision = %0.3f, recall = %0.3f, F1 = %0.3f, accuracy = %0.3f" % 
              (report[0], report[1], report[2], acc_score))
        print("The confusion matrix on the testing set:          \n", pd.DataFrame(cm))
        print("*********** AUC for ROC = %0.3f" % auc_score)
                
        plot_ROC_curve(y_test, y_score)
        plot_PR_curve(y_test, y_score)
        #print (y_score[:,:30])

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'class_weight':['balanced', None],
                     'random_state':[55, 21, 71, 35, 61],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000], 'random_state':[55, 21, 71, 35, 61],'class_weight':['balanced', None]}]

scores = ['recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.516 (+/-0.033) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.516 (+/-0.033) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.516 (+/-0.033) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.516 (+/-0.033) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.516 (+/-0.033) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 10, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.616 (+/-0.140) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.616 (+/-0.140) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.616 (+/-0.140) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.616 (+/-0.140) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.616 (+/-0.140) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.516 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.516 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.516 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.516 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.516 (+/-0.032) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 100, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.523 (+/-0.099) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.523 (+/-0.099) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.523 (+/-0.099) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.523 (+/-0.099) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.523 (+/-0.099) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.617 (+/-0.141) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.617 (+/-0.141) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.617 (+/-0.141) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.617 (+/-0.141) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.617 (+/-0.141) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 55, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 21, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 71, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 35, 'gamma': 0.0001, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'rbf', 'C': 1000, 'random_state': 61, 'gamma': 0.0001, 'class_weight': None}
# 0.636 (+/-0.154) for {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': 'balanced'}
# 0.636 (+/-0.154) for {'kernel': 'linear', 'C': 1, 'random_state': 21, 'class_weight': 'balanced'}
# 0.636 (+/-0.154) for {'kernel': 'linear', 'C': 1, 'random_state': 71, 'class_weight': 'balanced'}
# 0.636 (+/-0.154) for {'kernel': 'linear', 'C': 1, 'random_state': 35, 'class_weight': 'balanced'}
# 0.636 (+/-0.154) for {'kernel': 'linear', 'C': 1, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1, 'random_state': 61, 'class_weight': None}
# 0.555 (+/-0.039) for {'kernel': 'linear', 'C': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.555 (+/-0.039) for {'kernel': 'linear', 'C': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.555 (+/-0.039) for {'kernel': 'linear', 'C': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.555 (+/-0.039) for {'kernel': 'linear', 'C': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.555 (+/-0.039) for {'kernel': 'linear', 'C': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 10, 'random_state': 61, 'class_weight': None}
# 0.442 (+/-0.032) for {'kernel': 'linear', 'C': 100, 'random_state': 55, 'class_weight': 'balanced'}
# 0.442 (+/-0.032) for {'kernel': 'linear', 'C': 100, 'random_state': 21, 'class_weight': 'balanced'}
# 0.442 (+/-0.032) for {'kernel': 'linear', 'C': 100, 'random_state': 71, 'class_weight': 'balanced'}
# 0.442 (+/-0.032) for {'kernel': 'linear', 'C': 100, 'random_state': 35, 'class_weight': 'balanced'}
# 0.442 (+/-0.032) for {'kernel': 'linear', 'C': 100, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 100, 'random_state': 61, 'class_weight': None}
# 0.466 (+/-0.019) for {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# 0.466 (+/-0.019) for {'kernel': 'linear', 'C': 1000, 'random_state': 21, 'class_weight': 'balanced'}
# 0.466 (+/-0.019) for {'kernel': 'linear', 'C': 1000, 'random_state': 71, 'class_weight': 'balanced'}
# 0.466 (+/-0.019) for {'kernel': 'linear', 'C': 1000, 'random_state': 35, 'class_weight': 'balanced'}
# 0.466 (+/-0.019) for {'kernel': 'linear', 'C': 1000, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'kernel': 'linear', 'C': 1000, 'random_state': 61, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       1.00      0.76      0.86       481
#           1       0.01      0.50      0.02         2
#
# avg / total       0.99      0.76      0.86       483
#
# ()

# %%
# Set the parameters by cross-validation
#linearsvc


tuned_parameters = [{'C': [1.0, 10, 100, 1000],
                     #'penalty': ['l2', 'l1'],
                     'class_weight':['balanced', None],
                     #'loss': ['squared_hinge', 'hinge'],
                     'random_state':[55, 21, 71, 35, 61],
                     #'dual': [True, False],
                     'multi_class': ['crammer_singer', 'ovr']
                     }]

                    
scores = ['recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(LinearSVC(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 55, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.524 (+/-0.097) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 55, 'class_weight': 'balanced'}
# 0.524 (+/-0.097) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 21, 'class_weight': 'balanced'}
# 0.524 (+/-0.097) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 71, 'class_weight': 'balanced'}
# 0.524 (+/-0.097) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 35, 'class_weight': 'balanced'}
# 0.524 (+/-0.097) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 61, 'class_weight': 'balanced'}
# 0.548 (+/-0.052) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 55, 'class_weight': 'balanced'}
# 0.548 (+/-0.052) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 21, 'class_weight': 'balanced'}
# 0.548 (+/-0.052) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 71, 'class_weight': 'balanced'}
# 0.548 (+/-0.052) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 35, 'class_weight': 'balanced'}
# 0.548 (+/-0.052) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1.0, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1.0, 'random_state': 61, 'class_weight': None}
# 0.561 (+/-0.008) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.561 (+/-0.008) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.561 (+/-0.008) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.561 (+/-0.008) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.561 (+/-0.008) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.442 (+/-0.015) for {'multi_class': 'ovr', 'C': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.444 (+/-0.017) for {'multi_class': 'ovr', 'C': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.441 (+/-0.023) for {'multi_class': 'ovr', 'C': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.444 (+/-0.017) for {'multi_class': 'ovr', 'C': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.444 (+/-0.020) for {'multi_class': 'ovr', 'C': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 10, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 10, 'random_state': 61, 'class_weight': None}
# 0.448 (+/-0.029) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 55, 'class_weight': 'balanced'}
# 0.448 (+/-0.029) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 21, 'class_weight': 'balanced'}
# 0.448 (+/-0.029) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 71, 'class_weight': 'balanced'}
# 0.448 (+/-0.029) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 35, 'class_weight': 'balanced'}
# 0.448 (+/-0.029) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 61, 'class_weight': 'balanced'}
# 0.495 (+/-0.011) for {'multi_class': 'ovr', 'C': 100, 'random_state': 55, 'class_weight': 'balanced'}
# 0.496 (+/-0.009) for {'multi_class': 'ovr', 'C': 100, 'random_state': 21, 'class_weight': 'balanced'}
# 0.496 (+/-0.008) for {'multi_class': 'ovr', 'C': 100, 'random_state': 71, 'class_weight': 'balanced'}
# 0.496 (+/-0.008) for {'multi_class': 'ovr', 'C': 100, 'random_state': 35, 'class_weight': 'balanced'}
# 0.496 (+/-0.009) for {'multi_class': 'ovr', 'C': 100, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 100, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 100, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 100, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 100, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 100, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 100, 'random_state': 61, 'class_weight': None}
# 0.467 (+/-0.026) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# 0.534 (+/-0.109) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 21, 'class_weight': 'balanced'}
# 0.539 (+/-0.123) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 71, 'class_weight': 'balanced'}
# 0.529 (+/-0.102) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 35, 'class_weight': 'balanced'}
# 0.547 (+/-0.137) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 55, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 21, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 71, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'crammer_singer', 'C': 1000, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'multi_class': 'ovr', 'C': 1000, 'random_state': 61, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       1.00      0.68      0.81       481
#           1       0.01      0.50      0.01         2
#
# avg / total       0.99      0.68      0.80       483
#
# ()

# %%
# Set the parameters by cross-validation
#PERCEPTRON
tuned_parameters = [{'n_iter': [2, 5, 10,50],
                     'penalty': [None, 'l2', 'l1', 'elasticnet'],
                     'alpha': [0.001, 0.0001, 0.00001],
                     'random_state':[55, 21, 71, 35, 61],
                     'class_weight':['balanced', None]
                    }]

scores = ['recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(Perceptron(), tuned_parameters, cv=2, scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(metrics.classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for recall
# ()
# Best parameters set found on development set:
# ()
# {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# ()
# Grid scores on development set:
# ()
# 0.675 (+/-0.046) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.622 (+/-0.245) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.695 (+/-0.077) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.560 (+/-0.121) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.574 (+/-0.149) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.646 (+/-0.112) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.637 (+/-0.273) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.698 (+/-0.090) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.576 (+/-0.151) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.645 (+/-0.060) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.627 (+/-0.254) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.620 (+/-0.240) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.646 (+/-0.112) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.637 (+/-0.273) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.698 (+/-0.090) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.576 (+/-0.151) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.605 (+/-0.086) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.661 (+/-0.044) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.687 (+/-0.085) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.590 (+/-0.135) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.561 (+/-0.098) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.695 (+/-0.085) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.634 (+/-0.036) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.580 (+/-0.135) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.533 (+/-0.078) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.704 (+/-0.103) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.691 (+/-0.098) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.531 (+/-0.077) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.561 (+/-0.098) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.695 (+/-0.085) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.634 (+/-0.036) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.580 (+/-0.135) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.720 (+/-0.027) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.537 (+/-0.035) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.580 (+/-0.125) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.631 (+/-0.195) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.635 (+/-0.174) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.565 (+/-0.129) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.506 (+/-0.011) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.670 (+/-0.090) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.570 (+/-0.083) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.528 (+/-0.057) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.540 (+/-0.080) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.703 (+/-0.225) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.635 (+/-0.174) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.565 (+/-0.129) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.506 (+/-0.011) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.670 (+/-0.090) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.637 (+/-0.147) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.565 (+/-0.021) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.516 (+/-0.085) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.642 (+/-0.226) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.527 (+/-0.013) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.574 (+/-0.166) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.606 (+/-0.212) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.590 (+/-0.025) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.565 (+/-0.116) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.508 (+/-0.016) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.652 (+/-0.304) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.574 (+/-0.166) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.606 (+/-0.212) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.571 (+/-0.142) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': None, 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.497 (+/-0.006) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.496 (+/-0.007) for {'penalty': None, 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.565 (+/-0.131) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.496 (+/-0.007) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.550 (+/-0.101) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.550 (+/-0.101) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.497 (+/-0.005) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.490 (+/-0.020) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.499 (+/-0.003) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.675 (+/-0.046) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.622 (+/-0.245) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.695 (+/-0.077) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.560 (+/-0.121) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.574 (+/-0.149) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.719 (+/-0.030) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.632 (+/-0.264) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.685 (+/-0.101) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.561 (+/-0.121) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.576 (+/-0.151) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.720 (+/-0.029) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.626 (+/-0.251) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.688 (+/-0.095) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.561 (+/-0.121) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.576 (+/-0.151) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.719 (+/-0.030) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.632 (+/-0.264) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.685 (+/-0.101) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.561 (+/-0.121) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.576 (+/-0.151) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.605 (+/-0.086) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.661 (+/-0.044) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.687 (+/-0.085) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.590 (+/-0.135) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.621 (+/-0.066) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.668 (+/-0.045) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.690 (+/-0.084) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.582 (+/-0.151) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.625 (+/-0.055) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.665 (+/-0.053) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.688 (+/-0.085) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.506 (+/-0.026) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.621 (+/-0.066) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.668 (+/-0.045) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.690 (+/-0.084) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.582 (+/-0.151) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.720 (+/-0.027) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.537 (+/-0.035) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.580 (+/-0.125) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.631 (+/-0.195) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.589 (+/-0.254) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.540 (+/-0.077) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.573 (+/-0.144) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.652 (+/-0.195) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.640 (+/-0.130) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.536 (+/-0.044) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.578 (+/-0.135) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.603 (+/-0.258) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.589 (+/-0.254) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.540 (+/-0.077) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.573 (+/-0.144) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.652 (+/-0.195) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.637 (+/-0.147) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.565 (+/-0.021) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.516 (+/-0.085) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.642 (+/-0.226) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.527 (+/-0.013) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.631 (+/-0.057) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.562 (+/-0.069) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.529 (+/-0.046) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.645 (+/-0.289) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.512 (+/-0.025) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.582 (+/-0.031) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.569 (+/-0.011) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.520 (+/-0.089) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.639 (+/-0.237) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.525 (+/-0.005) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.631 (+/-0.057) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.562 (+/-0.069) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.529 (+/-0.046) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.645 (+/-0.289) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.512 (+/-0.025) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.571 (+/-0.142) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.494 (+/-0.012) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.573 (+/-0.146) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.549 (+/-0.098) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.494 (+/-0.012) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.573 (+/-0.146) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.497 (+/-0.006) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.496 (+/-0.007) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.565 (+/-0.131) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.496 (+/-0.007) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.565 (+/-0.129) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.499 (+/-0.002) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.565 (+/-0.129) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.497 (+/-0.005) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.490 (+/-0.020) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.499 (+/-0.003) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.492 (+/-0.013) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.492 (+/-0.013) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 0.0001, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.675 (+/-0.046) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.622 (+/-0.245) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.695 (+/-0.077) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.560 (+/-0.121) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.574 (+/-0.149) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.716 (+/-0.035) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.625 (+/-0.250) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.695 (+/-0.079) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.560 (+/-0.121) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.575 (+/-0.151) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.674 (+/-0.046) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.622 (+/-0.245) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.695 (+/-0.078) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.560 (+/-0.121) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.574 (+/-0.149) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.716 (+/-0.035) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': 'balanced'}
# 0.625 (+/-0.250) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': 'balanced'}
# 0.695 (+/-0.079) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': 'balanced'}
# 0.560 (+/-0.121) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': 'balanced'}
# 0.575 (+/-0.151) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': 'balanced'}
# 0.605 (+/-0.086) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.661 (+/-0.044) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.687 (+/-0.085) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.590 (+/-0.135) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.624 (+/-0.057) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.664 (+/-0.048) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.686 (+/-0.086) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.508 (+/-0.031) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.606 (+/-0.088) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.661 (+/-0.044) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.686 (+/-0.087) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.592 (+/-0.134) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.624 (+/-0.057) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': 'balanced'}
# 0.664 (+/-0.048) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': 'balanced'}
# 0.686 (+/-0.086) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': 'balanced'}
# 0.508 (+/-0.031) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': 'balanced'}
# 0.500 (+/-0.001) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.720 (+/-0.027) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.537 (+/-0.035) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.580 (+/-0.125) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.631 (+/-0.195) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.581 (+/-0.005) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.536 (+/-0.038) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.581 (+/-0.131) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.632 (+/-0.194) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.639 (+/-0.121) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.536 (+/-0.035) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.581 (+/-0.126) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.632 (+/-0.196) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': 'balanced'}
# 0.581 (+/-0.005) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': 'balanced'}
# 0.536 (+/-0.038) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': 'balanced'}
# 0.581 (+/-0.131) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': 'balanced'}
# 0.632 (+/-0.194) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': 'balanced'}
# 0.637 (+/-0.147) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.565 (+/-0.021) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.516 (+/-0.085) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.642 (+/-0.226) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.527 (+/-0.013) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.635 (+/-0.138) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.566 (+/-0.010) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.506 (+/-0.070) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.579 (+/-0.113) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.569 (+/-0.092) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.624 (+/-0.120) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.562 (+/-0.012) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.514 (+/-0.082) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.644 (+/-0.220) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.526 (+/-0.009) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.635 (+/-0.138) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': 'balanced'}
# 0.566 (+/-0.010) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': 'balanced'}
# 0.506 (+/-0.070) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': 'balanced'}
# 0.579 (+/-0.113) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': 'balanced'}
# 0.569 (+/-0.092) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': 'balanced'}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.571 (+/-0.142) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.569 (+/-0.137) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.568 (+/-0.136) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.568 (+/-0.135) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 55, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 35, 'class_weight': None}
# 0.569 (+/-0.137) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 2, 'random_state': 61, 'class_weight': None}
# 0.497 (+/-0.006) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.496 (+/-0.007) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 5, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.565 (+/-0.131) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.496 (+/-0.007) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.576 (+/-0.152) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 55, 'class_weight': None}
# 0.570 (+/-0.140) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 21, 'class_weight': None}
# 0.576 (+/-0.152) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 10, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.497 (+/-0.005) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.490 (+/-0.020) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.499 (+/-0.003) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': None, 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.497 (+/-0.006) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.499 (+/-0.003) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l2', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.001) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.497 (+/-0.006) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.498 (+/-0.004) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'l1', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 55, 'class_weight': None}
# 0.497 (+/-0.006) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 21, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 71, 'class_weight': None}
# 0.499 (+/-0.003) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 35, 'class_weight': None}
# 0.500 (+/-0.000) for {'penalty': 'elasticnet', 'alpha': 1e-05, 'n_iter': 50, 'random_state': 61, 'class_weight': None}
# ()
# Detailed classification report:
# ()
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
# ()
#              precision    recall  f1-score   support
#
#           0       1.00      0.94      0.97       481
#           1       0.00      0.00      0.00         2
#
# avg / total       0.99      0.94      0.96       483
#
# ()

# %%
##run 2

# %%
RANDOM_STATE = 61

X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)
# Out:
# ================================================================================
# Perceptron50
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty=None,
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.236s
# test time:  0.004s
# accuracy:   0.290
# precision:  0.007
# recall:     1.000
# *** AUC for ROC = 0.619
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.29      0.45       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.29      0.44       644
#
# confusion matrix:
# [[184 457]
#  [  0   3]]
# ()
# ================================================================================
# Perceptron50l1
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty='l1',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 1.393s
# test time:  0.002s
# accuracy:   0.241
# precision:  0.006
# recall:     1.000
# *** AUC for ROC = 0.623
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.24      0.38       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.24      0.38       644
#
# confusion matrix:
# [[152 489]
#  [  0   3]]
# ()
# ================================================================================
# Perceptron50l2
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=50, n_jobs=1, penalty='l2',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.296s
# test time:  0.003s
# accuracy:   0.093
# precision:  0.005
# recall:     1.000
# *** AUC for ROC = 0.623
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.09      0.16       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.09      0.16       644
#
# confusion matrix:
# [[ 57 584]
#  [  0   3]]
# ()
# ================================================================================
# Perceptron20
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty=None,
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.120s
# test time:  0.003s
# accuracy:   0.307
# precision:  0.007
# recall:     1.000
# *** AUC for ROC = 0.635
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.30      0.47       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.31      0.46       644
#
# confusion matrix:
# [[195 446]
#  [  0   3]]
# ()
# ================================================================================
# Perceptron20l1
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty='l1',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.420s
# test time:  0.074s
# accuracy:   0.281
# precision:  0.006
# recall:     1.000
# *** AUC for ROC = 0.633
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.28      0.43       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.28      0.43       644
#
# confusion matrix:
# [[178 463]
#  [  0   3]]
# ()
# ================================================================================
# Perceptron20l2
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight='balanced', eta0=1.0,
#       fit_intercept=True, n_iter=20, n_jobs=1, penalty='l2',
#       random_state=61, shuffle=True, verbose=0, warm_start=False)
# train time: 0.115s
# test time:  0.081s
# accuracy:   0.189
# precision:  0.006
# recall:     1.000
# *** AUC for ROC = 0.627
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.19      0.31       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.19      0.31       644
#
# confusion matrix:
# [[119 522]
#  [  0   3]]
# ()
# ================================================================================
# Logistic Regression 1e2
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=100.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=61,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# train time: 1.046s
# test time:  0.003s
# accuracy:   0.761
# precision:  0.013
# recall:     0.667
# *** AUC for ROC = 0.660
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.76      0.86       641
#    Relevant       0.01      0.67      0.03         3
#
# avg / total       0.99      0.76      0.86       644
#
# confusion matrix:
# [[488 153]
#  [  1   2]]
# ()
# ================================================================================
# Logistic Regression 1e6
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=1000000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=61,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
# train time: 6.224s
# test time:  0.003s
# accuracy:   0.970
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.794
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.98      0.99       641
#    Relevant       0.00      0.00      0.00         3
#
# avg / total       0.99      0.97      0.98       644
#
# confusion matrix:
# [[625  16]
#  [  3   0]]
# ()
# ================================================================================
# Linear SVC C=0.025
# ________________________________________________________________________________
# Training:
# SVC(C=0.025, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 3.327s
# test time:  2.563s
# accuracy:   0.483
# precision:  0.006
# recall:     0.667
# ('Complexity: ', array([913,   6]))
# *** AUC for ROC = 0.649
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.48      0.65       641
#    Relevant       0.01      0.67      0.01         3
#
# avg / total       0.99      0.48      0.65       644
#
# confusion matrix:
# [[309 332]
#  [  1   2]]
# ()
# ================================================================================
# Linear SVC C=1.05
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 2.700s
# test time:  1.545s
# accuracy:   0.705
# precision:  0.010
# recall:     0.667
# ('Complexity: ', array([541,   5]))
# *** AUC for ROC = 0.687
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.71      0.83       641
#    Relevant       0.01      0.67      0.02         3
#
# avg / total       0.99      0.70      0.82       644
#
# confusion matrix:
# [[452 189]
#  [  1   2]]
# ()
# ================================================================================
# Linear SVC L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=61, tol=0.0001,
#      verbose=0)
# train time: 6.102s
# test time:  0.130s
# accuracy:   0.731
# precision:  0.011
# recall:     0.667
# *** AUC for ROC = 0.654
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.73      0.84       641
#    Relevant       0.01      0.67      0.02         3
#
# avg / total       0.99      0.73      0.84       644
#
# confusion matrix:
# [[469 172]
#  [  1   2]]
# ()
# ================================================================================
# SVM with RBF kernel C=1
# ________________________________________________________________________________
# Training:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 3.674s
# test time:  1.644s
# accuracy:   0.995
# precision:  0.000
# recall:     0.000
# ('Complexity: ', array([943,   6]))
# *** AUC for ROC = 0.645
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      1.00      1.00       641
#    Relevant       0.00      0.00      0.00         3
#
# avg / total       0.99      1.00      0.99       644
#
# confusion matrix:
# [[641   0]
#  [  3   0]]
# ()
# ================================================================================
# SVM with RBF kernel C=10
# ________________________________________________________________________________
# Training:
# SVC(C=10.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 2.544s
# test time:  1.283s
# accuracy:   0.441
# precision:  0.006
# recall:     0.667
# ('Complexity: ', array([942,   6]))
# *** AUC for ROC = 0.645
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.44      0.61       641
#    Relevant       0.01      0.67      0.01         3
#
# avg / total       0.99      0.44      0.61       644
#
# confusion matrix:
# [[282 359]
#  [  1   2]]
# ()
# ================================================================================
# SVM with RBF kernel C=100
# ________________________________________________________________________________
# Training:
# SVC(C=100.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=61, shrinking=True,
#   tol=0.001, verbose=False)
# train time: 1.025s
# test time:  0.689s
# accuracy:   0.654
# precision:  0.009
# recall:     0.667
# ('Complexity: ', array([662,   5]))
# *** AUC for ROC = 0.678
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.65      0.79       641
#    Relevant       0.01      0.67      0.02         3
#
# avg / total       0.99      0.65      0.79       644
#
# confusion matrix:
# [[419 222]
#  [  1   2]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 71.888s
# test time:  0.003s
# accuracy:   0.995
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.500
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      1.00      1.00       641
#    Relevant       0.00      0.00      0.00         3
#
# avg / total       0.99      1.00      0.99       644
#
# confusion matrix:
# [[641   0]
#  [  3   0]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10, 10), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 49.892s
# test time:  0.148s
# accuracy:   0.995
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.698
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      1.00      1.00       641
#    Relevant       0.00      0.00      0.00         3
#
# avg / total       0.99      1.00      0.99       644
#
# confusion matrix:
# [[641   0]
#  [  3   0]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 84.226s
# test time:  0.153s
# accuracy:   0.995
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.699
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      1.00      1.00       641
#    Relevant       0.00      0.00      0.00         3
#
# avg / total       0.99      1.00      0.99       644
#
# confusion matrix:
# [[641   0]
#  [  3   0]]
# ()
# ================================================================================
# MLP5adaptive
# ________________________________________________________________________________
# Training:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5), learning_rate='invscaling',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=61, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.2, verbose=False,
#        warm_start=False)
# train time: 107.530s
# test time:  0.009s
# accuracy:   0.995
# precision:  0.000
# recall:     0.000
# *** AUC for ROC = 0.500
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      1.00      1.00       641
#    Relevant       0.00      0.00      0.00         3
#
# avg / total       0.99      1.00      0.99       644
#
# confusion matrix:
# [[641   0]
#  [  3   0]]
# ()
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=61, tol=0.001, verbose=0)
# train time: 0.176s
# test time:  0.003s
# accuracy:   0.731
# precision:  0.011
# recall:     0.667
# *** AUC for ROC = 0.653
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.73      0.84       641
#    Relevant       0.01      0.67      0.02         3
#
# avg / total       0.99      0.73      0.84       644
#
# confusion matrix:
# [[469 172]
#  [  1   2]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.108s
# test time:  0.010s
# accuracy:   0.354
# precision:  0.007
# recall:     1.000
# *** AUC for ROC = 0.626
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.35      0.52       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.35      0.52       644
#
# confusion matrix:
# [[225 416]
#  [  0   3]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.117s
# test time:  0.003s
# accuracy:   0.354
# precision:  0.007
# recall:     1.000
# *** AUC for ROC = 0.626
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.35      0.52       641
#    Relevant       0.01      1.00      0.01         3
#
# avg / total       1.00      0.35      0.52       644
#
# confusion matrix:
# [[225 416]
#  [  0   3]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.166s
# test time:  0.003s
# accuracy:   0.444
# precision:  0.006
# recall:     0.667
# *** AUC for ROC = 0.611
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.44      0.61       641
#    Relevant       0.01      0.67      0.01         3
#
# avg / total       0.99      0.44      0.61       644
#
# confusion matrix:
# [[284 357]
#  [  1   2]]
# ()
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight='balanced', dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=61, tol=0.001, verbose=0)
# train time: 0.076s
# test time:  0.023s
# accuracy:   0.722
# precision:  0.006
# recall:     0.333
# *** AUC for ROC = 0.670
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.72      0.84       641
#    Relevant       0.01      0.33      0.01         3
#
# avg / total       0.99      0.72      0.83       644
#
# confusion matrix:
# [[464 177]
#  [  2   1]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.401s
# test time:  0.010s
# accuracy:   0.592
# precision:  0.004
# recall:     0.333
# *** AUC for ROC = 0.531
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.59      0.74       641
#    Relevant       0.00      0.33      0.01         3
#
# avg / total       0.99      0.59      0.74       644
#
# confusion matrix:
# [[380 261]
#  [  2   1]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.379s
# test time:  0.018s
# accuracy:   0.592
# precision:  0.004
# recall:     0.333
# *** AUC for ROC = 0.531
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.59      0.74       641
#    Relevant       0.00      0.33      0.01         3
#
# avg / total       0.99      0.59      0.74       644
#
# confusion matrix:
# [[380 261]
#  [  2   1]]
# ()
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=61, shuffle=True, verbose=0,
#        warm_start=False)
# train time: 0.477s
# test time:  0.008s
# accuracy:   0.613
# precision:  0.004
# recall:     0.333
# *** AUC for ROC = 0.524
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       0.99      0.61      0.76       641
#    Relevant       0.00      0.33      0.01         3
#
# avg / total       0.99      0.61      0.76       644
#
# confusion matrix:
# [[394 247]
#  [  2   1]]
# ()
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=61, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.448s
# test time:  0.039s
# accuracy:   0.374
# precision:  0.005
# recall:     0.667
# *** AUC for ROC = 0.621
#
# classification report:
#              precision    recall  f1-score   support
#
#  Irrelevant       1.00      0.37      0.54       641
#    Relevant       0.00      0.67      0.01         3
#
# avg / total       0.99      0.37      0.54       644
#
# confusion matrix:
# [[239 402]
#  [  1   2]]
# ()

# %%
#run 3
RANDOM_STATE = 21

X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)

# %%
#run 4
RANDOM_STATE =71


X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)

# %%
#run 5
RANDOM_STATE = 35


X_train, X_test, y_train, y_test = train_test_split(averageWordVecs, inhibitor.Label, test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE)

# run the comparision of the battery of classifiers and plot out the results
comparison_plots(create_results())
# run the classifications for the battery of classifiers
run_class(averageWordVecs, inhibitor.Label, TEST_SIZE)
